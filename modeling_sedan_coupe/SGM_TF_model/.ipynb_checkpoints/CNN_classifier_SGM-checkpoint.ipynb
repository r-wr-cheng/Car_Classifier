# %%
from sagemaker import get_execution_role
from sagemaker.session import Session

# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket here if you wish.
bucket = 'car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models'

#IAM execution role that gives SageMaker access to resources in your AWS account.
role = get_execution_role()

# %%
from sagemaker.tensorflow import TensorFlow

car_classifier = TensorFlow(entry_point='CNN_TF_script.py',
                            role=role,
                            train_volume_size = 30,
                            train_max_run = 600, #seconds to run before terminating
                            py_version = 'py3',
                            train_instance_count=2,
                            train_instance_type='ml.m4.xlarge',                           
                            framework_version = '1.12.0',
                            distributions={'parameter_server': {'enabled': True}}
                           )

# %%
# %%time
import boto3

# use the region-specific sample data bucket
train_data_location = 's3://{}/data/train_head.csv'.format(bucket)
test_data_location = 's3://{}/data/test.csv'.format(bucket)

car_classifier.fit({'train' : train_data_location,
                   'test' : test_data_location
                  })
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768
# 2019-03-20 02:45:42 Starting - Starting the training job...
# 2019-03-20 02:45:46 Starting - Launching requested ML instances......
# 2019-03-20 02:46:50 Starting - Preparing the instances for training......
# 2019-03-20 02:48:04 Downloading - Downloading input data...
# 2019-03-20 02:48:27 Training - Training image download completed. Training in progress.
# 2019-03-20 02:48:32,042 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-03-20 02:48:32,047 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:32,480 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-20 02:48:32,481 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-03-20 02:48:32,481 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-20 02:48:32,500 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-03-20 02:48:32,653 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:32,674 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:32,687 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz",
#     "module_name": "CNN_TF_script",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "CNN_TF_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"model_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"}
# SM_USER_ENTRY_POINT=CNN_TF_script.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=CNN_TF_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz","module_name":"CNN_TF_script","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"CNN_TF_script.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model
#
# Invoking script with the following command:
#
# /usr/bin/python CNN_TF_script.py --model_dir s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model
#
#
# 2019-03-20 02:48:30,533 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-03-20 02:48:30,539 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:30,720 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-20 02:48:30,720 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-03-20 02:48:30,720 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-20 02:48:30,733 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-03-20 02:48:30,872 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:30,893 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-20 02:48:30,906 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz",
#     "module_name": "CNN_TF_script",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "CNN_TF_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"model_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"}
# SM_USER_ENTRY_POINT=CNN_TF_script.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=CNN_TF_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz","module_name":"CNN_TF_script","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"CNN_TF_script.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model
#
# Invoking script with the following command:
#
# /usr/bin/python CNN_TF_script.py --model_dir s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model
#
#
# (30, 40000)
# (30, 2)
# INFO:tensorflow:TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223'], 'worker': ['algo-2:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'master'}}
# INFO:tensorflow:Using config: {'_model_dir': 's3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:master"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efcde427a58>, '_task_type': 'master', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://algo-1:2222', '_evaluation_master': '', '_num_ps_replicas': 2, '_num_worker_replicas': 2, '_is_chief': True}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Start Tensorflow server.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model/model.ckpt.
# (30, 40000)
# (30, 2)
# INFO:tensorflow:TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223'], 'worker': ['algo-2:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'worker'}}
# INFO:tensorflow:Using config: {'_model_dir': 's3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:0"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0284f85a58>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 1, '_master': 'grpc://algo-2:2222', '_evaluation_master': '', '_num_ps_replicas': 2, '_num_worker_replicas': 2, '_is_chief': False}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Start Tensorflow server.
# INFO:tensorflow:Waiting 5 secs before starting training.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:loss = 0.775914, step = 0
# INFO:tensorflow:loss = 0.775914
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:loss = 1.1265903, step = 2
# INFO:tensorflow:loss = 1.1265903
# INFO:tensorflow:global_step/sec: 4.81884
# INFO:tensorflow:loss = 0.6088884, step = 15 (2.780 sec)
# INFO:tensorflow:loss = 0.6088884 (2.780 sec)
# INFO:tensorflow:global_step/sec: 5.66318
# INFO:tensorflow:loss = 0.48403507, step = 28 (1.875 sec)
# INFO:tensorflow:loss = 0.48403507 (1.875 sec)
# INFO:tensorflow:global_step/sec: 6.42837
# INFO:tensorflow:loss = 0.60450137, step = 40 (1.915 sec)
# INFO:tensorflow:loss = 0.60450137 (1.915 sec)
# INFO:tensorflow:global_step/sec: 6.46701
# INFO:tensorflow:loss = 0.70572305, step = 38 (9.154 sec)
# INFO:tensorflow:loss = 0.70572305 (9.153 sec)
# INFO:tensorflow:loss = 0.5897708, step = 52 (1.943 sec)
# INFO:tensorflow:loss = 0.5897708 (1.943 sec)
# INFO:tensorflow:global_step/sec: 6.28464
# INFO:tensorflow:loss = 0.5776781, step = 64 (1.980 sec)
# INFO:tensorflow:loss = 0.5776781 (1.980 sec)
# INFO:tensorflow:global_step/sec: 6.14603
# INFO:tensorflow:loss = 0.6997419, step = 76 (1.971 sec)
# INFO:tensorflow:loss = 0.6997419 (1.971 sec)
# INFO:tensorflow:global_step/sec: 6.26269
# INFO:tensorflow:loss = 0.72757095, step = 88 (1.866 sec)
# INFO:tensorflow:loss = 0.72757095 (1.866 sec)
# INFO:tensorflow:global_step/sec: 6.46743
# INFO:tensorflow:global_step/sec: 6.26322
# INFO:tensorflow:loss = 0.67795134, step = 101 (1.936 sec)
# INFO:tensorflow:loss = 0.67795134 (1.936 sec)
# INFO:tensorflow:loss = 0.6575259, step = 95 (8.945 sec)
# INFO:tensorflow:loss = 0.6575259 (8.945 sec)
# INFO:tensorflow:global_step/sec: 5.89522
# INFO:tensorflow:loss = 0.6920295, step = 113 (1.900 sec)
# INFO:tensorflow:loss = 0.6920295 (1.900 sec)
# INFO:tensorflow:global_step/sec: 6.41092
# INFO:tensorflow:loss = 0.6863382, step = 125 (1.936 sec)
# INFO:tensorflow:loss = 0.6863382 (1.936 sec)
# INFO:tensorflow:global_step/sec: 6.45212
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1002: s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/model/model.ckpt-1002
# INFO:tensorflow:Loss for final step: 1.5970083.
# 2019-03-20 02:51:29,046 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-03-20 02:51:29,046 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-03-20 02:51:40 Uploading - Uploading generated training model
# 2019-03-20 02:51:40 Completed - Training job completed
# 2019-03-20 02:51:31,514 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2019-03-20 02:51:31,515 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-03-20 02:51:31,515 sagemaker-containers INFO     Reporting training SUCCESS
# Billable seconds: 432
# CPU times: user 885 ms, sys: 57.3 ms, total: 942 ms
# Wall time: 6min 15s

# %%
# %%time
car_predictor = car_classifier.deploy(initial_instance_count=1,
                                      instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, use_compiled_model, update_endpoint, **kwargs)
#     375             accelerator_type=accelerator_type,
#     376             endpoint_name=endpoint_name,
# --> 377             update_endpoint=update_endpoint)
#     378
#     379     @property
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags)
#     250             self.name += compiled_model_suffix
#     251
# --> 252         self._create_sagemaker_model(instance_type, accelerator_type)
#     253         production_variant = sagemaker.production_variant(self.name, instance_type, initial_instance_count,
#     254                                                           accelerator_type=accelerator_type)
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/model.py in _create_sagemaker_model(self, instance_type, accelerator_type)
#     112         self.sagemaker_session.create_model(self.name, self.role,
#     113                                             container_def, vpc_config=self.vpc_config,
# --> 114                                             enable_network_isolation=enable_network_isolation)
#     115
#     116     def _framework(self):
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in create_model(self, name, role, container_defs, vpc_config, enable_network_isolation, primary_container)
#     601
#     602         try:
# --> 603             self.sagemaker_client.create_model(**create_model_request)
#     604         except ClientError as e:
#     605             error_code = e.response['Error']['Code']
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     659             error_code = parsed_response.get("Error", {}).get("Code")
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#     663             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateModel operation: Could not find model data at s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/output/model.tar.gz.

# %%
from sagemaker.tensorflow.serving import Model

model = Model(model_data='s3://sagemaker-us-east-2-050922845674/' +
              'sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz', role=role)

predictor = model.deploy(initial_instance_count=1, instance_type='ml.c5.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-tensorflow-serving-2019-03-20-03-03-04-779
# INFO:sagemaker:Creating endpoint with name sagemaker-tensorflow-serving-2019-03-20-03-03-04-779
# --------------------------------------------------------------------------------------------------------------*
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-693eb61adf04> in <module>()
#       4               'sagemaker-tensorflow-scriptmode-2019-03-20-02-45-41-768/source/sourcedir.tar.gz', role=role)
#       5
# ----> 6 predictor = model.deploy(initial_instance_count=1, instance_type='ml.c5.xlarge')
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags)
#     269             self.sagemaker_session.update_endpoint(self.endpoint_name, endpoint_config_name)
#     270         else:
# --> 271             self.sagemaker_session.endpoint_from_production_variants(self.endpoint_name, [production_variant], tags)
#     272
#     273         if self.predictor_cls:
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, wait)
#    1035
#    1036             self.sagemaker_client.create_endpoint_config(**config_options)
# -> 1037         return self.create_endpoint(endpoint_name=name, config_name=name, wait=wait)
#    1038
#    1039     def expand_role(self, role):
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, wait)
#     749         self.sagemaker_client.create_endpoint(EndpointName=endpoint_name, EndpointConfigName=config_name)
#     750         if wait:
# --> 751             self.wait_for_endpoint(endpoint_name)
#     752         return endpoint_name
#     753
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in wait_for_endpoint(self, endpoint, poll)
#     905         if status != 'InService':
#     906             reason = desc.get('FailureReason', None)
# --> 907             raise ValueError('Error hosting endpoint {}: {} Reason: {}'.format(endpoint, status, reason))
#     908         return desc
#     909
#
# ValueError: Error hosting endpoint sagemaker-tensorflow-serving-2019-03-20-03-03-04-779: Failed Reason:  The primary container for production variant AllTraffic did not pass the ping health check. Please check CloudWatch logs for this endpoint.

# %%
with open('/home/ec2-user/train_head.csv') as f:
    for line in f:
        
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]

# %%
predictor

# %% [markdown]
# Register the model

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

client = boto3.client('sagemaker')
job_name = 'sagemaker-tensorflow-scriptmode-2019-03-17-23-24-01-675'
sess = sagemaker.Session()
role = get_execution_role()

#to specify a model to register, 
#you pass in the specs of the training job which created that model
info = client.describe_training_job(TrainingJobName=job_name)

model_data = info['ModelArtifacts']['S3ModelArtifacts']
training_image = info['AlgorithmSpecification']['TrainingImage']

primary_container = {
    'Image': training_image,
    'ModelDataUrl': 's3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-20-56-23-190/source/sourcedir.tar.gz'
}

create_model_response = client.create_model(
    ModelName = job_name,
    ExecutionRoleArn = role,
    PrimaryContainer = primary_container)

print(create_model_response['ModelArn'])
# Out:
# arn:aws:sagemaker:us-east-2:050922845674:model/sagemaker-tensorflow-scriptmode-2019-03-17-23-24-01-675

# %%
create_model_response
# Out:
# {'ModelArn': 'arn:aws:sagemaker:us-east-2:050922845674:model/sagemaker-tensorflow-scriptmode-2019-03-17-23-24-01-675',
#  'ResponseMetadata': {'RequestId': '68f7341c-e28b-4281-aed9-009edba990af',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '68f7341c-e28b-4281-aed9-009edba990af',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '117',
#    'date': 'Wed, 20 Mar 2019 02:09:17 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# Do a batch transform

# %%
import boto3
import sagemaker
import json
from urllib.parse import urlparse
from time import gmtime, strftime

batch_job_name = 'Batch-Transform-' + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
input_location = 's3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/data/train_head.csv'
output_location = 's3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/batch_output/'

### Create a transform job
sm = boto3.client('sagemaker')

request = \
{
    "TransformJobName": batch_job_name,
    "ModelName": 'sagemaker-tensorflow-scriptmode-2019-03-17-23-24-01-675',
    #"MaxConcurrentTransforms": 0,
    "MaxPayloadInMB": 6,
    "BatchStrategy": "MultiRecord",
    "TransformOutput": {
        "S3OutputPath": output_location
    },
    "TransformInput": {
        "DataSource": {
            "S3DataSource": {
                "S3DataType": "S3Prefix",
                "S3Uri": input_location 
            }
        },
        "ContentType": "text/csv",
        "SplitType": "Line",
        "CompressionType": "None"
    },
    "TransformResources": {
            "InstanceType": "ml.m4.xlarge",
            "InstanceCount": 1
    }
}

sm.create_transform_job(**request)

print("Created Transform job with name: ", batch_job_name)
# Out:
# Created Transform job with name:  Batch-Transform-2019-03-20-02-12-08

# %%
# %%time
iris_predictor = iris_estimator.deploy(initial_instance_count=1,
                                       instance_type='ml.m4.xlarge')

# %%
iris_predictor.predict([6.4, 3.2, 4.5, 1.5]) #expected label to be 1
