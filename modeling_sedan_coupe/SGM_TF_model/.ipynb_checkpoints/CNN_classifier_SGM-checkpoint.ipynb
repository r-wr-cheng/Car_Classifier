# %%
from sagemaker import get_execution_role
from sagemaker.session import Session

# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket here if you wish.
bucket = 'car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models'

# Location where results of model training are saved.
model_artifacts_location = 's3://{}/artifacts'.format(bucket)

# Location where Tensorboard
model_dir = 's3://{}/tensorboard'.format(bucket)

#IAM execution role that gives SageMaker access to resources in your AWS account.
role = get_execution_role()

# %%
from sagemaker.tensorflow import TensorFlow

# %%
car_classifier = TensorFlow(entry_point='CNN_TF_script.py',
                            role=role,
                           train_volume_size = 30,
                           train_max_run = 600, #seconds to run before terminating
                           output_path = model_artifacts_location,
                           py_version = 'py3',
                           model_dir = model_dir,
                        train_instance_count=2,
                        train_instance_type='ml.m4.xlarge',
                        #training_steps=10,
                           
                           framework_version = '1.12.0',
                           distributions={'parameter_server': {'enabled': True}}
                            #evaluation_steps=100
                          )

# %%
# %%time
import boto3

# use the region-specific sample data bucket
train_data_location = 's3://{}/data/train_head.csv'.format(bucket)
test_data_location = 's3://{}/data/test.csv'.format(bucket)

car_classifier.fit({'train' : train_data_location,
                   'test' : test_data_location
                  })
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619
# 2019-03-17 23:09:25 Starting - Starting the training job...
# 2019-03-17 23:09:26 Starting - Launching requested ML instances......
# 2019-03-17 23:10:29 Starting - Preparing the instances for training......
# 2019-03-17 23:11:30 Downloading - Downloading input data..
# 2019-03-17 23:12:06,635 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-03-17 23:12:06,641 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:06,820 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-17 23:12:06,820 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-03-17 23:12:06,820 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-17 23:12:06,832 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-03-17 23:12:07,024 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:07,042 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:07,055 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz",
#     "module_name": "CNN_TF_script",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "CNN_TF_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"model_dir":"s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"}
# SM_USER_ENTRY_POINT=CNN_TF_script.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=CNN_TF_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz","module_name":"CNN_TF_script","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"CNN_TF_script.py"}
# SM_USER_ARGS=["--model_dir","s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard
#
# Invoking script with the following command:
#
# /usr/bin/python CNN_TF_script.py --model_dir s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard
#
#
# (30, 40000)
# (30, 2)
# INFO:tensorflow:TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223'], 'worker': ['algo-2:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'worker'}}
# INFO:tensorflow:Using config: {'_model_dir': 's3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:0"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4bd099a470>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 1, '_master': 'grpc://algo-2:2222', '_evaluation_master': '', '_num_ps_replicas': 2, '_num_worker_replicas': 2, '_is_chief': False}
# Traceback (most recent call last):
#   File "CNN_TF_script.py", line 202, in <module>
#     eval_spec = tf.estimator.EvalSpec(eval_input_fn)
# NameError: name 'eval_input_fn' is not defined
# 2019-03-17 23:12:10,150 sagemaker-containers ERROR    ExecuteUserScriptError:
# Command "/usr/bin/python CNN_TF_script.py --model_dir s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"
# 2019-03-17 23:12:21 Training - Training image download completed. Training in progress.
# 2019-03-17 23:12:21 Uploading - Uploading generated training model
# 2019-03-17 23:12:21 Failed - Training job failed
# 2019-03-17 23:12:09,158 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-03-17 23:12:09,164 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:09,372 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-17 23:12:09,373 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-03-17 23:12:09,373 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-03-17 23:12:09,387 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-03-17 23:12:09,533 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:09,554 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-03-17 23:12:09,568 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz",
#     "module_name": "CNN_TF_script",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "CNN_TF_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"model_dir":"s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"}
# SM_USER_ENTRY_POINT=CNN_TF_script.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=CNN_TF_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-050922845674/sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619/source/sourcedir.tar.gz","module_name":"CNN_TF_script","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"CNN_TF_script.py"}
# SM_USER_ARGS=["--model_dir","s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard
#
# Invoking script with the following command:
#
# /usr/bin/python CNN_TF_script.py --model_dir s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard
#
#
# (30, 40000)
# (30, 2)
# INFO:tensorflow:TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223'], 'worker': ['algo-2:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'master'}}
# INFO:tensorflow:Using config: {'_model_dir': 's3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:master"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f670afbe470>, '_task_type': 'master', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://algo-1:2222', '_evaluation_master': '', '_num_ps_replicas': 2, '_num_worker_replicas': 2, '_is_chief': True}
# Traceback (most recent call last):
#   File "CNN_TF_script.py", line 202, in <module>
#     eval_spec = tf.estimator.EvalSpec(eval_input_fn)
# NameError: name 'eval_input_fn' is not defined
# 2019-03-17 23:12:12,640 sagemaker-containers ERROR    ExecuteUserScriptError:
# Command "/usr/bin/python CNN_TF_script.py --model_dir s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, run_tensorboard_locally)
#     334                 tensorboard.join()
#     335         else:
# --> 336             fit_super()
#     337
#     338     @classmethod
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     313
#     314         def fit_super():
# --> 315             super(TensorFlow, self).fit(inputs, wait, logs, job_name)
#     316
#     317         if run_tensorboard_locally and wait is False:
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name)
#     236         self.latest_training_job = _TrainingJob.start_new(self, inputs)
#     237         if wait:
# --> 238             self.latest_training_job.wait(logs=logs)
#     239
#     240     def _compilation_job_name(self):
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#     588     def wait(self, logs=True):
#     589         if logs:
# --> 590             self.sagemaker_session.logs_for_job(self.job_name, wait=True)
#     591         else:
#     592             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll)
#    1188
#    1189         if wait:
# -> 1190             self._check_job_status(job_name, description, 'TrainingJobStatus')
#    1191             if dot:
#    1192                 print()
#
# ~/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#     888             reason = desc.get('FailureReason', '(No reason provided)')
#     889             job_type = status_key_name.replace('JobStatus', ' job')
# --> 890             raise ValueError('Error for {} {}: {} Reason: {}'.format(job_type, job, status, reason))
#     891
#     892     def wait_for_endpoint(self, endpoint, poll=5):
#
# ValueError: Error for Training job sagemaker-tensorflow-scriptmode-2019-03-17-23-09-24-619: Failed Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/usr/bin/python CNN_TF_script.py --model_dir s3://car-classifier-us-east-2/python_readable_data/stanford_cars_dataset/SGM_data_and_models/tensorboard"

# %%
# %%time
iris_predictor = iris_estimator.deploy(initial_instance_count=1,
                                       instance_type='ml.m4.xlarge')

# %%
iris_predictor.predict([6.4, 3.2, 4.5, 1.5]) #expected label to be 1
