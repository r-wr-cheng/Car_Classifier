# %%
import pandas as pd
import numpy as np
import pickle as p

from sklearn.metrics import roc_auc_score
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Compile the training data

# %%
meta_data = pd.read_csv('/home/ec2-user/training_data_meta.csv')

# %%
#Join cleaned class data with training metadata

class_data = pd.read_csv('/home/ec2-user/stanford_labels_cleaned.csv')

# %%
meta_data = pd.merge(meta_data, class_data, on = 'class', how = 'left')

# %%
meta_data['Body Type'].value_counts()
# Out:
# Sedan          2075
# SUV            1558
# Coupe          1540
# Convertible    1036
# Crew Cab        381
# Hatchback       380
# Cab             297
# Van             291
# Wagon           253
# Minivan         250
# Quad Cab         44
# Club Cab         39
# Name: Body Type, dtype: int64

# %%
meta_data = meta_data.loc[meta_data['Body Type'].isin(['Coupe', 'Sedan'])].copy()

# %%
meta_data['is_sedan_target'] = (meta_data['Body Type'] == 'Sedan').astype(int)

# %%
image_dict = p.load(open('/home/ec2-user/scaled_grayscale_dict.p', 'rb'))

# %%
training_data = []
for i in meta_data[['is_sedan_target', 'fname']].iterrows():
    row = [i[1]['is_sedan_target']]
    row.extend(image_dict[i[1]['fname']].flatten())
    training_data.append(row)
training_data = np.array(training_data).astype(float)

# %% [markdown]
# Fit the model

# %%
X_train, X_test, y_train, y_test = train_test_split(training_data[:,1:], 
                                                    training_data[:,0], 
                                                    test_size=0.33, 
                                                    random_state=42)

# %%
scaler = StandardScaler()

scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)

# %%
params = {'booster' : 'gbtree', 
          'verbosity' : 1, 
          'learning_rate' : 0.01, #aka eta
          'max_depth' : 3,
          'subsample' : .5,
          'reg_lambda' : 0.01, #L2 reg
          'reg_alpha' : 0.02, #L1 reg
          'objective' : 'binary:logistic',
          'eval_metric' : 'auc'
         }

eval_list = [(dtest, 'eval'), (dtrain, 'train')]

model = xgb.train(params, dtrain, num_boost_round = 300, evals = eval_list, early_stopping_rounds = 50)
# Out:
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	eval-auc:0.538094	train-auc:0.578429
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 50 rounds.
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]	eval-auc:0.531254	train-auc:0.62725
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [2]	eval-auc:0.526033	train-auc:0.651923
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [3]	eval-auc:0.531549	train-auc:0.663576
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [4]	eval-auc:0.526064	train-auc:0.677084
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [5]	eval-auc:0.536308	train-auc:0.689886
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [6]	eval-auc:0.540217	train-auc:0.700231
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [7]	eval-auc:0.54456	train-auc:0.702722
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [8]	eval-auc:0.540448	train-auc:0.712593
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [9]	eval-auc:0.545233	train-auc:0.709907
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [10]	eval-auc:0.54883	train-auc:0.714524
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11]	eval-auc:0.551044	train-auc:0.719782
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [12]	eval-auc:0.550458	train-auc:0.722567
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [13]	eval-auc:0.550582	train-auc:0.724128
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [14]	eval-auc:0.552379	train-auc:0.728149
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [15]	eval-auc:0.552308	train-auc:0.725682
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [16]	eval-auc:0.55262	train-auc:0.72514
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [17]	eval-auc:0.55402	train-auc:0.72673
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [18]	eval-auc:0.555588	train-auc:0.725346
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [19]	eval-auc:0.559053	train-auc:0.725503
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [20]	eval-auc:0.557513	train-auc:0.728481
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [21]	eval-auc:0.559616	train-auc:0.734927
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [22]	eval-auc:0.559488	train-auc:0.742877
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [23]	eval-auc:0.557152	train-auc:0.744109
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [24]	eval-auc:0.55779	train-auc:0.744461
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [25]	eval-auc:0.55878	train-auc:0.744659
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [26]	eval-auc:0.557689	train-auc:0.74516
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [27]	eval-auc:0.556345	train-auc:0.745989
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [28]	eval-auc:0.557767	train-auc:0.747229
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [29]	eval-auc:0.557241	train-auc:0.746349
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]	eval-auc:0.556404	train-auc:0.748767
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [31]	eval-auc:0.556352	train-auc:0.746833
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [32]	eval-auc:0.556235	train-auc:0.747315
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [33]	eval-auc:0.555825	train-auc:0.748768
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [34]	eval-auc:0.556919	train-auc:0.748819
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [35]	eval-auc:0.556124	train-auc:0.748852
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [36]	eval-auc:0.558272	train-auc:0.750851
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [37]	eval-auc:0.557705	train-auc:0.752073
# [03:56:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [38]	eval-auc:0.558923	train-auc:0.751583
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [39]	eval-auc:0.557546	train-auc:0.753837
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [40]	eval-auc:0.558326	train-auc:0.754203
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [41]	eval-auc:0.559098	train-auc:0.755297
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [42]	eval-auc:0.557956	train-auc:0.756274
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [43]	eval-auc:0.559374	train-auc:0.757722
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [44]	eval-auc:0.558915	train-auc:0.758099
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [45]	eval-auc:0.56053	train-auc:0.75902
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [46]	eval-auc:0.55857	train-auc:0.760143
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [47]	eval-auc:0.55927	train-auc:0.761896
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [48]	eval-auc:0.558951	train-auc:0.761308
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [49]	eval-auc:0.560937	train-auc:0.762457
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [50]	eval-auc:0.559563	train-auc:0.762952
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [51]	eval-auc:0.560718	train-auc:0.766236
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [52]	eval-auc:0.561119	train-auc:0.76581
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [53]	eval-auc:0.56174	train-auc:0.766239
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [54]	eval-auc:0.561656	train-auc:0.765608
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [55]	eval-auc:0.560828	train-auc:0.766323
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [56]	eval-auc:0.560704	train-auc:0.766643
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [57]	eval-auc:0.561815	train-auc:0.766195
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [58]	eval-auc:0.560556	train-auc:0.766552
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [59]	eval-auc:0.560467	train-auc:0.765827
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [60]	eval-auc:0.560611	train-auc:0.766324
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [61]	eval-auc:0.559052	train-auc:0.76582
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [62]	eval-auc:0.559156	train-auc:0.765996
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [63]	eval-auc:0.560148	train-auc:0.767533
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [64]	eval-auc:0.559953	train-auc:0.768266
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [65]	eval-auc:0.559612	train-auc:0.767304
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [66]	eval-auc:0.559296	train-auc:0.767968
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [67]	eval-auc:0.558327	train-auc:0.767911
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [68]	eval-auc:0.559153	train-auc:0.767228
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [69]	eval-auc:0.558939	train-auc:0.769085
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [70]	eval-auc:0.559006	train-auc:0.771381
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [71]	eval-auc:0.559791	train-auc:0.772842
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [72]	eval-auc:0.55995	train-auc:0.774413
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [73]	eval-auc:0.559546	train-auc:0.774559
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [74]	eval-auc:0.558728	train-auc:0.775005
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [75]	eval-auc:0.5574	train-auc:0.77608
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [76]	eval-auc:0.558782	train-auc:0.776961
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [77]	eval-auc:0.558945	train-auc:0.776505
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [78]	eval-auc:0.559199	train-auc:0.778505
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [79]	eval-auc:0.557842	train-auc:0.780008
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [80]	eval-auc:0.557775	train-auc:0.780429
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [81]	eval-auc:0.558324	train-auc:0.782053
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [82]	eval-auc:0.558441	train-auc:0.782214
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [83]	eval-auc:0.557726	train-auc:0.784996
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [84]	eval-auc:0.557389	train-auc:0.784796
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [85]	eval-auc:0.558473	train-auc:0.784648
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [86]	eval-auc:0.559395	train-auc:0.786452
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [87]	eval-auc:0.559814	train-auc:0.786723
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [88]	eval-auc:0.560426	train-auc:0.789091
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [89]	eval-auc:0.560682	train-auc:0.790588
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [90]	eval-auc:0.560311	train-auc:0.791797
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [91]	eval-auc:0.559771	train-auc:0.792679
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [92]	eval-auc:0.55955	train-auc:0.792819
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [93]	eval-auc:0.559079	train-auc:0.793975
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [94]	eval-auc:0.558086	train-auc:0.79453
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [95]	eval-auc:0.557787	train-auc:0.794103
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [96]	eval-auc:0.558451	train-auc:0.793242
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [97]	eval-auc:0.558298	train-auc:0.794839
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [98]	eval-auc:0.559095	train-auc:0.795048
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [99]	eval-auc:0.559703	train-auc:0.79651
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [100]	eval-auc:0.559534	train-auc:0.797318
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [101]	eval-auc:0.5598	train-auc:0.797485
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [102]	eval-auc:0.558887	train-auc:0.797768
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [103]	eval-auc:0.558584	train-auc:0.798363
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [104]	eval-auc:0.559436	train-auc:0.799507
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [105]	eval-auc:0.559889	train-auc:0.798773
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [106]	eval-auc:0.560909	train-auc:0.799629
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [107]	eval-auc:0.561033	train-auc:0.80048
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [108]	eval-auc:0.561498	train-auc:0.801913
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [109]	eval-auc:0.560415	train-auc:0.802104
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [110]	eval-auc:0.561171	train-auc:0.803238
# [03:56:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [111]	eval-auc:0.561336	train-auc:0.802982
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [112]	eval-auc:0.561342	train-auc:0.802935
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [113]	eval-auc:0.560721	train-auc:0.803638
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [114]	eval-auc:0.560883	train-auc:0.805142
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [115]	eval-auc:0.560449	train-auc:0.807017
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [116]	eval-auc:0.560608	train-auc:0.807931
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [117]	eval-auc:0.561306	train-auc:0.807689
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [118]	eval-auc:0.56107	train-auc:0.807537
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [119]	eval-auc:0.561492	train-auc:0.807476
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [120]	eval-auc:0.563178	train-auc:0.808311
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [121]	eval-auc:0.563239	train-auc:0.808236
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [122]	eval-auc:0.563242	train-auc:0.80972
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [123]	eval-auc:0.563213	train-auc:0.81133
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [124]	eval-auc:0.563392	train-auc:0.812352
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [125]	eval-auc:0.563519	train-auc:0.813699
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [126]	eval-auc:0.563438	train-auc:0.814504
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [127]	eval-auc:0.563097	train-auc:0.815026
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [128]	eval-auc:0.563484	train-auc:0.815024
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [129]	eval-auc:0.563135	train-auc:0.81531
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [130]	eval-auc:0.563363	train-auc:0.816073
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [131]	eval-auc:0.563542	train-auc:0.81667
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [132]	eval-auc:0.563314	train-auc:0.817121
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [133]	eval-auc:0.563132	train-auc:0.817859
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [134]	eval-auc:0.564039	train-auc:0.81894
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [135]	eval-auc:0.563923	train-auc:0.819747
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [136]	eval-auc:0.563614	train-auc:0.82067
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [137]	eval-auc:0.56317	train-auc:0.820701
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [138]	eval-auc:0.562745	train-auc:0.821019
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [139]	eval-auc:0.563562	train-auc:0.822002
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [140]	eval-auc:0.563978	train-auc:0.821506
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [141]	eval-auc:0.564437	train-auc:0.821965
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [142]	eval-auc:0.564209	train-auc:0.823151
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [143]	eval-auc:0.564668	train-auc:0.825312
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [144]	eval-auc:0.564527	train-auc:0.826173
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [145]	eval-auc:0.564784	train-auc:0.826121
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [146]	eval-auc:0.564541	train-auc:0.825745
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [147]	eval-auc:0.564238	train-auc:0.82569
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [148]	eval-auc:0.565038	train-auc:0.826593
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [149]	eval-auc:0.564189	train-auc:0.827635
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [150]	eval-auc:0.563969	train-auc:0.828161
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [151]	eval-auc:0.564019	train-auc:0.828993
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [152]	eval-auc:0.564209	train-auc:0.830756
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [153]	eval-auc:0.564775	train-auc:0.830704
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [154]	eval-auc:0.564518	train-auc:0.831849
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [155]	eval-auc:0.564888	train-auc:0.832036
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [156]	eval-auc:0.565142	train-auc:0.832638
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [157]	eval-auc:0.565291	train-auc:0.833549
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [158]	eval-auc:0.565181	train-auc:0.833948
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [159]	eval-auc:0.563753	train-auc:0.834705
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [160]	eval-auc:0.56386	train-auc:0.835446
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [161]	eval-auc:0.564403	train-auc:0.836063
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [162]	eval-auc:0.564671	train-auc:0.835862
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [163]	eval-auc:0.565174	train-auc:0.837028
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [164]	eval-auc:0.565901	train-auc:0.838007
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [165]	eval-auc:0.565584	train-auc:0.83863
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [166]	eval-auc:0.56496	train-auc:0.838532
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [167]	eval-auc:0.565477	train-auc:0.839434
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [168]	eval-auc:0.565122	train-auc:0.839619
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [169]	eval-auc:0.565693	train-auc:0.840288
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [170]	eval-auc:0.566147	train-auc:0.840506
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [171]	eval-auc:0.566285	train-auc:0.841101
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [172]	eval-auc:0.565994	train-auc:0.841743
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [173]	eval-auc:0.566095	train-auc:0.841688
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [174]	eval-auc:0.565895	train-auc:0.842391
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [175]	eval-auc:0.566744	train-auc:0.842707
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [176]	eval-auc:0.567166	train-auc:0.843082
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [177]	eval-auc:0.567322	train-auc:0.843878
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [178]	eval-auc:0.567095	train-auc:0.845022
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [179]	eval-auc:0.568707	train-auc:0.846407
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [180]	eval-auc:0.568951	train-auc:0.846914
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [181]	eval-auc:0.569629	train-auc:0.847067
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [182]	eval-auc:0.570042	train-auc:0.847272
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [183]	eval-auc:0.570403	train-auc:0.84744
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [184]	eval-auc:0.570054	train-auc:0.848562
# [03:56:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [185]	eval-auc:0.570679	train-auc:0.848207
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [186]	eval-auc:0.570085	train-auc:0.848683
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [187]	eval-auc:0.570403	train-auc:0.849508
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [188]	eval-auc:0.570137	train-auc:0.84906
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [189]	eval-auc:0.570116	train-auc:0.848969
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [190]	eval-auc:0.570825	train-auc:0.849269
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [191]	eval-auc:0.570617	train-auc:0.849733
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [192]	eval-auc:0.570293	train-auc:0.85028
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [193]	eval-auc:0.570394	train-auc:0.851499
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [194]	eval-auc:0.570186	train-auc:0.852399
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [195]	eval-auc:0.570585	train-auc:0.853807
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [196]	eval-auc:0.570542	train-auc:0.854618
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [197]	eval-auc:0.570158	train-auc:0.85463
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [198]	eval-auc:0.569797	train-auc:0.854976
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [199]	eval-auc:0.569339	train-auc:0.855111
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [200]	eval-auc:0.569209	train-auc:0.855476
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [201]	eval-auc:0.569841	train-auc:0.85601
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [202]	eval-auc:0.569577	train-auc:0.855783
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [203]	eval-auc:0.569511	train-auc:0.856248
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [204]	eval-auc:0.56921	train-auc:0.856525
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [205]	eval-auc:0.569381	train-auc:0.856766
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [206]	eval-auc:0.569312	train-auc:0.857046
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [207]	eval-auc:0.569011	train-auc:0.856996
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [208]	eval-auc:0.569242	train-auc:0.857085
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [209]	eval-auc:0.568948	train-auc:0.857343
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [210]	eval-auc:0.568696	train-auc:0.857625
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [211]	eval-auc:0.56885	train-auc:0.857699
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [212]	eval-auc:0.56859	train-auc:0.857723
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [213]	eval-auc:0.56878	train-auc:0.857961
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [214]	eval-auc:0.568858	train-auc:0.85797
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [215]	eval-auc:0.568893	train-auc:0.858066
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [216]	eval-auc:0.569161	train-auc:0.859019
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [217]	eval-auc:0.569557	train-auc:0.859144
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [218]	eval-auc:0.569317	train-auc:0.860122
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [219]	eval-auc:0.56885	train-auc:0.860679
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [220]	eval-auc:0.568344	train-auc:0.861249
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [221]	eval-auc:0.568351	train-auc:0.861721
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [222]	eval-auc:0.568362	train-auc:0.862704
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [223]	eval-auc:0.568003	train-auc:0.862555
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [224]	eval-auc:0.567767	train-auc:0.862533
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [225]	eval-auc:0.567663	train-auc:0.86333
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [226]	eval-auc:0.566766	train-auc:0.863856
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [227]	eval-auc:0.566668	train-auc:0.863987
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [228]	eval-auc:0.566742	train-auc:0.863926
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [229]	eval-auc:0.567052	train-auc:0.864594
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [230]	eval-auc:0.567339	train-auc:0.864466
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [231]	eval-auc:0.567092	train-auc:0.864244
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [232]	eval-auc:0.567159	train-auc:0.86479
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [233]	eval-auc:0.566692	train-auc:0.86546
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [234]	eval-auc:0.566389	train-auc:0.865736
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [235]	eval-auc:0.566424	train-auc:0.866469
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [236]	eval-auc:0.566808	train-auc:0.866676
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [237]	eval-auc:0.56725	train-auc:0.866356
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [238]	eval-auc:0.567576	train-auc:0.866851
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [239]	eval-auc:0.567169	train-auc:0.867358
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [240]	eval-auc:0.567013	train-auc:0.867143
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [241]	eval-auc:0.567111	train-auc:0.867344
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [242]	eval-auc:0.566791	train-auc:0.868203
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [243]	eval-auc:0.567056	train-auc:0.868789
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [244]	eval-auc:0.566918	train-auc:0.869013
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [245]	eval-auc:0.566909	train-auc:0.869502
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [246]	eval-auc:0.567409	train-auc:0.870187
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [247]	eval-auc:0.567432	train-auc:0.870337
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [248]	eval-auc:0.567689	train-auc:0.870863
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [249]	eval-auc:0.567658	train-auc:0.871001
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [250]	eval-auc:0.567674	train-auc:0.871333
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [251]	eval-auc:0.567445	train-auc:0.871432
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [252]	eval-auc:0.567414	train-auc:0.87168
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [253]	eval-auc:0.567385	train-auc:0.872066
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [254]	eval-auc:0.567673	train-auc:0.873161
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [255]	eval-auc:0.568018	train-auc:0.873066
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [256]	eval-auc:0.568523	train-auc:0.874107
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [257]	eval-auc:0.568029	train-auc:0.873785
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [258]	eval-auc:0.56755	train-auc:0.874738
# [03:56:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [259]	eval-auc:0.567801	train-auc:0.875695
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [260]	eval-auc:0.568188	train-auc:0.876402
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [261]	eval-auc:0.568122	train-auc:0.87712
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [262]	eval-auc:0.568112	train-auc:0.877445
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [263]	eval-auc:0.567917	train-auc:0.877539
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [264]	eval-auc:0.566978	train-auc:0.878443
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [265]	eval-auc:0.566186	train-auc:0.879359
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [266]	eval-auc:0.566134	train-auc:0.880197
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [267]	eval-auc:0.566428	train-auc:0.880467
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [268]	eval-auc:0.565768	train-auc:0.881033
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [269]	eval-auc:0.566181	train-auc:0.881451
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [270]	eval-auc:0.565852	train-auc:0.881684
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [271]	eval-auc:0.565968	train-auc:0.882172
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [272]	eval-auc:0.566773	train-auc:0.882788
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [273]	eval-auc:0.566785	train-auc:0.883702
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [274]	eval-auc:0.566788	train-auc:0.88423
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [275]	eval-auc:0.566461	train-auc:0.884097
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [276]	eval-auc:0.566046	train-auc:0.88437
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [277]	eval-auc:0.565829	train-auc:0.884886
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [278]	eval-auc:0.565997	train-auc:0.885278
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [279]	eval-auc:0.566217	train-auc:0.885841
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [280]	eval-auc:0.566742	train-auc:0.886033
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [281]	eval-auc:0.566563	train-auc:0.886487
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [282]	eval-auc:0.566346	train-auc:0.886387
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [283]	eval-auc:0.565971	train-auc:0.886668
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [284]	eval-auc:0.56643	train-auc:0.887155
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [285]	eval-auc:0.566245	train-auc:0.8874
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [286]	eval-auc:0.566295	train-auc:0.887926
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [287]	eval-auc:0.566473	train-auc:0.887797
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [288]	eval-auc:0.566898	train-auc:0.888556
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [289]	eval-auc:0.566912	train-auc:0.889339
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [290]	eval-auc:0.566568	train-auc:0.890053
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [291]	eval-auc:0.567114	train-auc:0.89015
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [292]	eval-auc:0.567007	train-auc:0.890086
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [293]	eval-auc:0.566762	train-auc:0.890475
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [294]	eval-auc:0.566805	train-auc:0.890741
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [295]	eval-auc:0.56738	train-auc:0.89124
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [296]	eval-auc:0.567423	train-auc:0.891212
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [297]	eval-auc:0.567847	train-auc:0.891376
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [298]	eval-auc:0.567752	train-auc:0.891512
# [03:56:50] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [299]	eval-auc:0.56723	train-auc:0.891478

# %%
model.predict(dtrain)

# %%
print('training auroc : %f'%(roc_auc_score(y_train, model.predict(dtrain))))
# Out:
# training auroc : 0.577371

# %%
print('testing auroc : %f'%(roc_auc_score(y_test, model.predict(dtest))))
# Out:
# testing auroc : 0.527468
