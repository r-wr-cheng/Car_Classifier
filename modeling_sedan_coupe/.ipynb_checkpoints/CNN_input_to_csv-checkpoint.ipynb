# %%
import pandas as pd
import numpy as np
import pickle as p

import tensorflow as tf
tf.logging.set_verbosity(tf.logging.INFO)
#tf.enable_eager_execution()
from sklearn.model_selection import train_test_split

from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

# %% [markdown]
# Compile the training data

# %%
meta_data = pd.read_csv('/home/ec2-user/training_data_meta.csv')

#Join cleaned class data with training metadata

class_data = pd.read_csv('/home/ec2-user/stanford_labels_cleaned.csv')

meta_data = pd.merge(meta_data, class_data, on = 'class', how = 'left')

meta_data = meta_data.loc[meta_data['Body Type'].isin(['Coupe', 'Sedan'])].copy()

meta_data['is_sedan_target'] = (meta_data['Body Type'] == 'Sedan').astype(int)

image_dict = p.load(open('/home/ec2-user/scaled_bounded_grayscale_dict.p', 'rb'))

training_data = []
for i in meta_data[['is_sedan_target', 'fname']].iterrows():
    row = [i[1]['is_sedan_target']]
    row.extend(image_dict[i[1]['fname']].flatten())
    training_data.append(row)

training_data = np.array(training_data).astype(float)

# %% [markdown]
# Prep the data

# %%
X_train, X_test, y_train, y_test = train_test_split(training_data[:,1:], 
                                                    training_data[:,0], 
                                                    test_size=0.30, 
                                                    random_state=420)

y_train = y_train.astype('int32')
y_test = y_test.astype('int32')

negatives = []
for ind, elem in enumerate(y_train):
    if elem == 0:
        negatives.append(ind)
np.random.shuffle(negatives)

neg_dupe_target = 2 * y_train.sum() - y_train.shape[0]

X_train = np.concatenate([X_train, X_train[negatives[0:neg_dupe_target],:]],
                         axis = 0
                        )
y_train = np.concatenate([y_train, y_train[negatives[0:neg_dupe_target]]],
                         axis = 0
                        )

y_train = np.concatenate([1 - y_train.reshape(-1,1), y_train.reshape(-1,1)], axis = 1)
y_test = np.concatenate([1 - y_test.reshape(-1,1), y_test.reshape(-1,1)], axis = 1)

# %% [markdown]
# Define the model

# %%
def cnn_model_fn(features, labels, mode):
    """Model function for CNN."""
    
    #Define model architecture
    
    # Input Layer
    # Reshape X to 4-D tensor: [batch_size, width, height, channels]
    input_layer = tf.reshape(features, [-1, 200, 200, 1])

    # Convolutional Layer #1
    # Computes 32 features using a 3x3 filter with ReLU activation.
    # Padding is added to preserve width and height.
    # Input Tensor Shape: [batch_size, 200, 200, 1]
    # Output Tensor Shape: [batch_size, 200, 200, 32]
    conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu)

    # Pooling Layer #1
    # First max pooling layer with a 2x2 filter and stride of 2
    # Input Tensor Shape: [batch_size, 200, 200, 32]
    # Output Tensor Shape: [batch_size, 100, 100, 32]
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)

    # Convolutional Layer #2
    # Computes 64 features using a 3x3 filter.
    # Padding is added to preserve width and height.
    # Input Tensor Shape: [batch_size, 100, 100, 32]
    # Output Tensor Shape: [batch_size, 100, 100, 64]
    conv2 = tf.layers.conv2d(
      inputs=pool1,
      filters=32,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu)

    # Pooling Layer #2
    # Second max pooling layer with a 2x2 filter and stride of 2
    # Input Tensor Shape: [batch_size, 100, 100, 64]
    # Output Tensor Shape: [batch_size, 50, 50, 64]
    pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
    
    conv3 = tf.layers.conv2d(
      inputs=pool2,
      filters=64,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu)

    # Pooling Layer #3
    # Second max pooling layer with a 2x2 filter and stride of 2
    # Input Tensor Shape: [batch_size, 50, 50, 64]
    # Output Tensor Shape: [batch_size, 25, 25, 64]
    pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=[2, 2], strides=2)

    # Flatten tensor into a batch of vectors
    # Input Tensor Shape: [batch_size, 25, 25, 64]
    # Output Tensor Shape: [batch_size, 25 * 25 * 64]
    pool3_flat = tf.reshape(pool3, [-1, 25 * 25 * 64])

    # Dense Layer
    # Densely connected layer with 256 neurons
    # Input Tensor Shape: [batch_size, 25 * 25 * 64]
    # Output Tensor Shape: [batch_size, 256]
    dense = tf.layers.dense(inputs=pool3_flat, units=256, activation=tf.nn.relu)

    # Add dropout operation; 0.6 probability that element will be kept
    dropout = tf.layers.dropout(
      inputs=dense, rate=0.5, training=(mode == tf.estimator.ModeKeys.TRAIN))

    # Logits layer
    # Input Tensor Shape: [batch_size, 1024]
    # Output Tensor Shape: [batch_size, 10]
    logits = tf.layers.dense(inputs=dropout, units=2)
    
    #Predict Op
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            # Generate predictions (for PREDICT and EVAL mode)
            "classes": tf.argmax(input=logits, axis=1),
            # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
            # `logging_hook`.
            "probabilities": tf.nn.softmax(logits, name="softmax_tensor"),
            "logits" : logits
            
        }
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        #Define model outputs
        # Calculate Loss (for both TRAIN and EVAL modes)
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels[:,1], logits=logits)
        
        logging_hook = tf.train.LoggingTensorHook(
            {"loss" : loss,
            },
            every_n_iter=10)
        optimizer = tf.train.AdamOptimizer(learning_rate=0.0005)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op, training_hooks = [logging_hook])
    # Add evaluation metrics (for EVAL mode)
    if mode == tf.estimator.ModeKeys.EVAL:
        #Define model outputs
        # Calculate Loss (for both TRAIN and EVAL modes)
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels[:,1], logits=logits)
        
        predictions = {
          # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
          # `logging_hook`.
          "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
        }
        #swap this for AUROC?
        eval_metric_ops = {
          "eval_accuracy": tf.metrics.auc(
              labels=labels, predictions=predictions["probabilities"])}

        return tf.estimator.EstimatorSpec(
          mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
session_config = tf.ConfigProto(
      inter_op_parallelism_threads=16,
      intra_op_parallelism_threads=16,
      )

config = tf.estimator.RunConfig(session_config = session_config,
                                log_step_count_steps = 10,
                                save_summary_steps = 10
                               )

# Create the Estimator
car_classifier = tf.estimator.Estimator(
  model_fn=cnn_model_fn, model_dir="/home/ec2-user/convnet_model", config = config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/home/ec2-user/convnet_model', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': intra_op_parallelism_threads: 16
# inter_op_parallelism_threads: 16
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efd7e015748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
#custom input function using training_image_processor with tf.data.Dataset
def image_processor_train_input_fn(image_processor, X_train, y_train, batch_size):
    
    dataset = tf.data.Dataset.from_generator(
        generator = lambda : image_processor.flow(X_train.reshape((X_train.shape[0], 200, 200, 1)), 
                                                  y_train, batch_size, shuffle = True), 
        output_types = (np.float32, np.int32))
    
    dataset = dataset.shuffle(512).repeat()
    
    return dataset

#Shearing, no zooming
training_image_processor = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale= 1./255,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    shear_range=15,
    horizontal_flip=True,
    data_format = 'channels_last',
)

def image_processor_eval_input_fn(image_processor, X_test, y_test, batch_size):
    
    dataset = tf.data.Dataset.from_tensor_slices((X_test.astype('float32'), 
                                                  y_test.astype('int32')))
        
    return dataset.batch(batch_size)

testing_image_processor = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    data_format = 'channels_last'
)

# %% [markdown]
# Train

# %%
car_classifier.train(
      input_fn=lambda:image_processor_train_input_fn(training_image_processor, X_train, y_train, 128),
      steps=90000
    )
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-4-e8d756075180>:20: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From <ipython-input-4-e8d756075180>:26: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
# WARNING:tensorflow:From <ipython-input-4-e8d756075180>:68: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-4-e8d756075180>:72: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-36331
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1070: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 36331 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:loss = 0.013564924, step = 36332
# INFO:tensorflow:loss = 0.013564924
# INFO:tensorflow:global_step/sec: 0.250619
# INFO:tensorflow:loss = 0.03590375, step = 36342 (39.902 sec)
# INFO:tensorflow:loss = 0.03590375 (39.902 sec)
# INFO:tensorflow:global_step/sec: 0.318858
# INFO:tensorflow:loss = 0.04050865, step = 36352 (31.362 sec)
# INFO:tensorflow:loss = 0.04050865 (31.362 sec)
# INFO:tensorflow:global_step/sec: 0.294371
# INFO:tensorflow:loss = 0.038492847, step = 36362 (33.971 sec)
# INFO:tensorflow:loss = 0.038492847 (33.971 sec)
# INFO:tensorflow:global_step/sec: 0.294575
# INFO:tensorflow:loss = 0.0446235, step = 36372 (33.947 sec)
# INFO:tensorflow:loss = 0.0446235 (33.947 sec)
# INFO:tensorflow:global_step/sec: 0.3037
# INFO:tensorflow:loss = 0.017546253, step = 36382 (32.927 sec)
# INFO:tensorflow:loss = 0.017546253 (32.927 sec)
# INFO:tensorflow:global_step/sec: 0.292999
# INFO:tensorflow:loss = 0.007918749, step = 36392 (34.130 sec)
# INFO:tensorflow:loss = 0.007918749 (34.129 sec)
# INFO:tensorflow:global_step/sec: 0.294571
# INFO:tensorflow:loss = 0.017107751, step = 36402 (33.948 sec)
# INFO:tensorflow:loss = 0.017107751 (33.948 sec)
# INFO:tensorflow:global_step/sec: 0.304152
# INFO:tensorflow:loss = 0.08671117, step = 36412 (32.878 sec)
# INFO:tensorflow:loss = 0.08671117 (32.878 sec)
# INFO:tensorflow:global_step/sec: 0.295209
# INFO:tensorflow:loss = 0.05425927, step = 36422 (33.874 sec)
# INFO:tensorflow:loss = 0.05425927 (33.874 sec)
# INFO:tensorflow:global_step/sec: 0.294637
# INFO:tensorflow:loss = 0.05759179, step = 36432 (33.940 sec)
# INFO:tensorflow:loss = 0.05759179 (33.940 sec)
# INFO:tensorflow:global_step/sec: 0.318599
# INFO:tensorflow:loss = 0.0853359, step = 36442 (31.388 sec)
# INFO:tensorflow:loss = 0.0853359 (31.387 sec)
# INFO:tensorflow:global_step/sec: 0.305537
# INFO:tensorflow:loss = 0.054808058, step = 36452 (32.729 sec)
# INFO:tensorflow:loss = 0.054808058 (32.729 sec)
# INFO:tensorflow:global_step/sec: 0.294931
# INFO:tensorflow:loss = 0.032515317, step = 36462 (33.906 sec)
# INFO:tensorflow:loss = 0.032515317 (33.906 sec)
# INFO:tensorflow:Saving checkpoints for 36464 into /home/ec2-user/convnet_model/model.ckpt.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:global_step/sec: 0.293784
# INFO:tensorflow:loss = 0.10535976, step = 36472 (34.039 sec)
# INFO:tensorflow:loss = 0.10535976 (34.038 sec)
# INFO:tensorflow:global_step/sec: 0.294156
# INFO:tensorflow:loss = 0.024591062, step = 36482 (33.996 sec)
# INFO:tensorflow:loss = 0.024591062 (33.996 sec)
# INFO:tensorflow:global_step/sec: 0.296079
# INFO:tensorflow:loss = 0.028221477, step = 36492 (33.775 sec)
# INFO:tensorflow:loss = 0.028221477 (33.775 sec)
# INFO:tensorflow:global_step/sec: 0.293631
# INFO:tensorflow:loss = 0.05295255, step = 36502 (34.056 sec)
# INFO:tensorflow:loss = 0.05295255 (34.057 sec)
# INFO:tensorflow:loss = 0.039576463, step = 36542 (34.025 sec)
# INFO:tensorflow:loss = 0.039576463 (34.025 sec)
# INFO:tensorflow:global_step/sec: 0.304931
# INFO:tensorflow:loss = 0.07631317, step = 36552 (32.794 sec)
# INFO:tensorflow:loss = 0.07631317 (32.794 sec)
# INFO:tensorflow:global_step/sec: 0.293639
# INFO:tensorflow:loss = 0.045724697, step = 36562 (34.056 sec)
# INFO:tensorflow:loss = 0.045724697 (34.056 sec)
# INFO:tensorflow:global_step/sec: 0.304517
# INFO:tensorflow:loss = 0.007562997, step = 36572 (32.839 sec)
# INFO:tensorflow:loss = 0.007562997 (32.839 sec)
# INFO:tensorflow:global_step/sec: 0.306047
# INFO:tensorflow:loss = 0.010323273, step = 36582 (32.675 sec)
# INFO:tensorflow:loss = 0.010323273 (32.675 sec)
# INFO:tensorflow:global_step/sec: 0.293876
# INFO:tensorflow:loss = 0.016241306, step = 36592 (34.028 sec)
# INFO:tensorflow:loss = 0.016241306 (34.028 sec)
# INFO:tensorflow:global_step/sec: 0.305772
# INFO:tensorflow:loss = 0.061753877, step = 36602 (32.704 sec)
# INFO:tensorflow:loss = 0.061753877 (32.704 sec)
# INFO:tensorflow:global_step/sec: 0.305161
# INFO:tensorflow:loss = 0.07293521, step = 36612 (32.770 sec)
# INFO:tensorflow:loss = 0.07293521 (32.770 sec)
# INFO:tensorflow:global_step/sec: 0.305105
# INFO:tensorflow:loss = 0.099629916, step = 36622 (32.776 sec)
# INFO:tensorflow:loss = 0.099629916 (32.776 sec)
# INFO:tensorflow:global_step/sec: 0.295349
# INFO:tensorflow:loss = 0.013445679, step = 36632 (33.858 sec)
# INFO:tensorflow:loss = 0.013445679 (33.858 sec)
# INFO:tensorflow:global_step/sec: 0.304732
# INFO:tensorflow:loss = 0.064465344, step = 36642 (32.816 sec)
# INFO:tensorflow:loss = 0.064465344 (32.816 sec)
# INFO:tensorflow:Saving checkpoints for 36644 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.293983
# INFO:tensorflow:loss = 0.034361508, step = 36652 (34.016 sec)
# INFO:tensorflow:loss = 0.034361508 (34.016 sec)
# INFO:tensorflow:global_step/sec: 0.293379
# INFO:tensorflow:loss = 0.020262873, step = 36662 (34.085 sec)
# INFO:tensorflow:loss = 0.020262873 (34.085 sec)
# INFO:tensorflow:global_step/sec: 0.296569
# INFO:tensorflow:loss = 0.04816918, step = 36672 (33.719 sec)
# INFO:tensorflow:loss = 0.04816918 (33.719 sec)
# INFO:tensorflow:global_step/sec: 0.305928
# INFO:tensorflow:loss = 0.037636153, step = 36682 (32.687 sec)
# INFO:tensorflow:loss = 0.037636153 (32.687 sec)
# INFO:tensorflow:global_step/sec: 0.330877
# INFO:tensorflow:loss = 0.036339287, step = 36692 (30.223 sec)
# INFO:tensorflow:loss = 0.036339287 (30.223 sec)
# INFO:tensorflow:global_step/sec: 0.296098
# INFO:tensorflow:loss = 0.053881325, step = 36702 (33.773 sec)
# INFO:tensorflow:loss = 0.053881325 (33.773 sec)
# INFO:tensorflow:global_step/sec: 0.295376
# INFO:tensorflow:loss = 0.032306682, step = 36712 (33.855 sec)
# INFO:tensorflow:loss = 0.032306682 (33.855 sec)
# INFO:tensorflow:global_step/sec: 0.310351
# INFO:tensorflow:loss = 0.047030147, step = 36722 (32.221 sec)
# INFO:tensorflow:loss = 0.047030147 (32.221 sec)
# INFO:tensorflow:global_step/sec: 0.296272
# INFO:tensorflow:loss = 0.05759579, step = 36732 (33.753 sec)
# INFO:tensorflow:loss = 0.05759579 (33.753 sec)
# INFO:tensorflow:global_step/sec: 0.307636
# INFO:tensorflow:loss = 0.046083182, step = 36742 (32.506 sec)
# INFO:tensorflow:loss = 0.046083182 (32.506 sec)
# INFO:tensorflow:global_step/sec: 0.296269
# INFO:tensorflow:loss = 0.0254545, step = 36752 (33.753 sec)
# INFO:tensorflow:loss = 0.0254545 (33.753 sec)
# INFO:tensorflow:global_step/sec: 0.295283
# INFO:tensorflow:loss = 0.09222374, step = 36762 (33.866 sec)
# INFO:tensorflow:loss = 0.09222374 (33.866 sec)
# INFO:tensorflow:global_step/sec: 0.305647
# INFO:tensorflow:loss = 0.0069528967, step = 36772 (32.718 sec)
# INFO:tensorflow:loss = 0.0069528967 (32.718 sec)
# INFO:tensorflow:global_step/sec: 0.330593
# INFO:tensorflow:loss = 0.020963829, step = 36782 (30.249 sec)
# INFO:tensorflow:loss = 0.020963829 (30.248 sec)
# INFO:tensorflow:global_step/sec: 0.296379
# INFO:tensorflow:loss = 0.039992876, step = 36792 (33.741 sec)
# INFO:tensorflow:loss = 0.039992876 (33.741 sec)
# INFO:tensorflow:global_step/sec: 0.294737
# INFO:tensorflow:loss = 0.039449222, step = 36802 (33.928 sec)
# INFO:tensorflow:loss = 0.039449222 (33.929 sec)
# INFO:tensorflow:global_step/sec: 0.318936
# INFO:tensorflow:loss = 0.0053179767, step = 36812 (31.354 sec)
# INFO:tensorflow:loss = 0.0053179767 (31.354 sec)
# INFO:tensorflow:global_step/sec: 0.294096
# INFO:tensorflow:loss = 0.0050283903, step = 36822 (34.002 sec)
# INFO:tensorflow:loss = 0.0050283903 (34.002 sec)
# INFO:tensorflow:Saving checkpoints for 36826 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.295382
# INFO:tensorflow:loss = 0.01374724, step = 36832 (33.855 sec)
# INFO:tensorflow:loss = 0.01374724 (33.854 sec)
# INFO:tensorflow:global_step/sec: 0.299486
# INFO:tensorflow:loss = 0.017543176, step = 36842 (33.391 sec)
# INFO:tensorflow:loss = 0.017543176 (33.391 sec)
# INFO:tensorflow:global_step/sec: 0.294415
# INFO:tensorflow:loss = 0.037855558, step = 36852 (33.966 sec)
# INFO:tensorflow:loss = 0.037855558 (33.966 sec)
# INFO:tensorflow:global_step/sec: 0.305262
# INFO:tensorflow:loss = 0.021026107, step = 36862 (32.759 sec)
# INFO:tensorflow:loss = 0.021026107 (32.759 sec)
# INFO:tensorflow:global_step/sec: 0.295258
# INFO:tensorflow:loss = 0.011120748, step = 36872 (33.869 sec)
# INFO:tensorflow:loss = 0.011120748 (33.869 sec)
# INFO:tensorflow:global_step/sec: 0.319905
# INFO:tensorflow:loss = 0.011501951, step = 36882 (31.259 sec)
# INFO:tensorflow:loss = 0.011501951 (31.259 sec)
# INFO:tensorflow:global_step/sec: 0.305987
# INFO:tensorflow:loss = 0.043278188, step = 36892 (32.681 sec)
# INFO:tensorflow:loss = 0.043278188 (32.681 sec)
# INFO:tensorflow:global_step/sec: 0.294956
# INFO:tensorflow:loss = 0.052368864, step = 36902 (33.903 sec)
# INFO:tensorflow:loss = 0.052368864 (33.903 sec)
# INFO:tensorflow:global_step/sec: 0.295028
# INFO:tensorflow:loss = 0.015344027, step = 36912 (33.895 sec)
# INFO:tensorflow:loss = 0.015344027 (33.895 sec)
# INFO:tensorflow:global_step/sec: 0.294425
# INFO:tensorflow:loss = 0.02081165, step = 36922 (33.964 sec)
# INFO:tensorflow:loss = 0.02081165 (33.964 sec)
# INFO:tensorflow:global_step/sec: 0.294861
# INFO:tensorflow:loss = 0.044140037, step = 36932 (33.914 sec)
# INFO:tensorflow:loss = 0.044140037 (33.915 sec)
# INFO:tensorflow:global_step/sec: 0.306812
# INFO:tensorflow:loss = 0.04762191, step = 36942 (32.593 sec)
# INFO:tensorflow:loss = 0.04762191 (32.593 sec)
# INFO:tensorflow:global_step/sec: 0.319407
# INFO:tensorflow:loss = 0.028290782, step = 36952 (31.308 sec)
# INFO:tensorflow:loss = 0.028290782 (31.308 sec)
# INFO:tensorflow:global_step/sec: 0.295297
# INFO:tensorflow:loss = 0.055897165, step = 36962 (33.864 sec)
# INFO:tensorflow:loss = 0.055897165 (33.864 sec)
# INFO:tensorflow:global_step/sec: 0.295548
# INFO:tensorflow:loss = 0.019068751, step = 36972 (33.836 sec)
# INFO:tensorflow:loss = 0.019068751 (33.835 sec)
# INFO:tensorflow:global_step/sec: 0.295061
# INFO:tensorflow:loss = 0.026034543, step = 36982 (33.891 sec)
# INFO:tensorflow:loss = 0.026034543 (33.891 sec)
# INFO:tensorflow:global_step/sec: 0.295067
# INFO:tensorflow:loss = 0.0052835094, step = 36992 (33.891 sec)
# INFO:tensorflow:loss = 0.0052835094 (33.891 sec)
# INFO:tensorflow:global_step/sec: 0.306447
# INFO:tensorflow:loss = 0.06148273, step = 37002 (32.632 sec)
# INFO:tensorflow:loss = 0.06148273 (32.632 sec)
# INFO:tensorflow:Saving checkpoints for 37007 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.293396
# INFO:tensorflow:loss = 0.02767921, step = 37012 (34.084 sec)
# INFO:tensorflow:loss = 0.02767921 (34.084 sec)
# INFO:tensorflow:global_step/sec: 0.296096
# INFO:tensorflow:loss = 0.03506458, step = 37022 (33.773 sec)
# INFO:tensorflow:loss = 0.03506458 (33.773 sec)
# INFO:tensorflow:global_step/sec: 0.299001
# INFO:tensorflow:loss = 0.01851555, step = 37032 (33.445 sec)
# INFO:tensorflow:loss = 0.01851555 (33.445 sec)
# INFO:tensorflow:global_step/sec: 0.294652
# INFO:tensorflow:loss = 0.07232606, step = 37042 (33.938 sec)
# INFO:tensorflow:loss = 0.07232606 (33.938 sec)
# INFO:tensorflow:global_step/sec: 0.295587
# INFO:tensorflow:loss = 0.07008403, step = 37052 (33.831 sec)
# INFO:tensorflow:loss = 0.07008403 (33.831 sec)
# INFO:tensorflow:global_step/sec: 0.29558
# INFO:tensorflow:loss = 0.017131958, step = 37062 (33.832 sec)
# INFO:tensorflow:loss = 0.017131958 (33.832 sec)
# INFO:tensorflow:global_step/sec: 0.295433
# INFO:tensorflow:loss = 0.049665596, step = 37072 (33.848 sec)
# INFO:tensorflow:loss = 0.049665596 (33.848 sec)
# INFO:tensorflow:global_step/sec: 0.306316
# INFO:tensorflow:loss = 0.019684637, step = 37082 (32.646 sec)
# INFO:tensorflow:loss = 0.019684637 (32.646 sec)
# INFO:tensorflow:global_step/sec: 0.29617
# INFO:tensorflow:loss = 0.034655645, step = 37092 (33.765 sec)
# INFO:tensorflow:loss = 0.034655645 (33.765 sec)
# INFO:tensorflow:global_step/sec: 0.294836
# INFO:tensorflow:loss = 0.045902606, step = 37102 (33.917 sec)
# INFO:tensorflow:loss = 0.045902606 (33.917 sec)
# INFO:tensorflow:global_step/sec: 0.29539
# INFO:tensorflow:loss = 0.012158097, step = 37112 (33.853 sec)
# INFO:tensorflow:loss = 0.012158097 (33.853 sec)
# INFO:tensorflow:global_step/sec: 0.294857
# INFO:tensorflow:loss = 0.045181602, step = 37122 (33.915 sec)
# INFO:tensorflow:loss = 0.045181602 (33.915 sec)
# INFO:tensorflow:global_step/sec: 0.296221
# INFO:tensorflow:loss = 0.031716395, step = 37132 (33.759 sec)
# INFO:tensorflow:loss = 0.031716395 (33.759 sec)
# INFO:tensorflow:global_step/sec: 0.294877
# INFO:tensorflow:loss = 0.030486751, step = 37142 (33.912 sec)
# INFO:tensorflow:loss = 0.030486751 (33.912 sec)
# INFO:tensorflow:global_step/sec: 0.318463
# INFO:tensorflow:loss = 0.030837525, step = 37152 (31.401 sec)
# INFO:tensorflow:loss = 0.030837525 (31.401 sec)
# INFO:tensorflow:global_step/sec: 0.307915
# INFO:tensorflow:loss = 0.009141483, step = 37162 (32.476 sec)
# INFO:tensorflow:loss = 0.009141483 (32.477 sec)
# INFO:tensorflow:global_step/sec: 0.317847
# INFO:tensorflow:loss = 0.033560358, step = 37172 (31.462 sec)
# INFO:tensorflow:loss = 0.033560358 (31.462 sec)
# INFO:tensorflow:global_step/sec: 0.296272
# INFO:tensorflow:loss = 0.019086564, step = 37182 (33.753 sec)
# INFO:tensorflow:loss = 0.019086564 (33.753 sec)
# INFO:tensorflow:Saving checkpoints for 37187 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.304328
# INFO:tensorflow:loss = 0.027987158, step = 37192 (32.859 sec)
# INFO:tensorflow:loss = 0.027987158 (32.859 sec)
# INFO:tensorflow:global_step/sec: 0.295577
# INFO:tensorflow:loss = 0.01998245, step = 37202 (33.832 sec)
# INFO:tensorflow:loss = 0.01998245 (33.832 sec)
# INFO:tensorflow:global_step/sec: 0.294805
# INFO:tensorflow:loss = 0.08417885, step = 37212 (33.921 sec)
# INFO:tensorflow:loss = 0.08417885 (33.921 sec)
# INFO:tensorflow:global_step/sec: 0.305501
# INFO:tensorflow:loss = 0.045448337, step = 37222 (32.733 sec)
# INFO:tensorflow:loss = 0.045448337 (32.733 sec)
# INFO:tensorflow:global_step/sec: 0.295856
# INFO:tensorflow:loss = 0.045053378, step = 37232 (33.800 sec)
# INFO:tensorflow:loss = 0.045053378 (33.800 sec)
# INFO:tensorflow:global_step/sec: 0.294511
# INFO:tensorflow:loss = 0.054390006, step = 37242 (33.955 sec)
# INFO:tensorflow:loss = 0.054390006 (33.955 sec)
# INFO:tensorflow:global_step/sec: 0.295929
# INFO:tensorflow:loss = 0.013148565, step = 37252 (33.792 sec)
# INFO:tensorflow:loss = 0.013148565 (33.792 sec)
# INFO:tensorflow:global_step/sec: 0.294087
# INFO:tensorflow:loss = 0.013508628, step = 37262 (34.003 sec)
# INFO:tensorflow:loss = 0.013508628 (34.003 sec)
# INFO:tensorflow:global_step/sec: 0.307382
# INFO:tensorflow:loss = 0.087096855, step = 37272 (32.533 sec)
# INFO:tensorflow:loss = 0.087096855 (32.533 sec)
# INFO:tensorflow:global_step/sec: 0.295157
# INFO:tensorflow:loss = 0.020784497, step = 37282 (33.880 sec)
# INFO:tensorflow:loss = 0.020784497 (33.880 sec)
# INFO:tensorflow:global_step/sec: 0.295985
# INFO:tensorflow:loss = 0.032164883, step = 37292 (33.785 sec)
# INFO:tensorflow:loss = 0.032164883 (33.785 sec)
# INFO:tensorflow:global_step/sec: 0.317484
# INFO:tensorflow:loss = 0.046003476, step = 37302 (31.498 sec)
# INFO:tensorflow:loss = 0.046003476 (31.498 sec)
# INFO:tensorflow:global_step/sec: 0.305084
# INFO:tensorflow:loss = 0.018910736, step = 37312 (32.778 sec)
# INFO:tensorflow:loss = 0.018910736 (32.778 sec)
# INFO:tensorflow:global_step/sec: 0.295376
# INFO:tensorflow:loss = 0.07044405, step = 37322 (33.855 sec)
# INFO:tensorflow:loss = 0.07044405 (33.855 sec)
# INFO:tensorflow:global_step/sec: 0.294211
# INFO:tensorflow:loss = 0.034830343, step = 37332 (33.989 sec)
# INFO:tensorflow:loss = 0.034830343 (33.989 sec)
# INFO:tensorflow:global_step/sec: 0.296105
# INFO:tensorflow:loss = 0.03824196, step = 37342 (33.771 sec)
# INFO:tensorflow:loss = 0.03824196 (33.772 sec)
# INFO:tensorflow:global_step/sec: 0.294633
# INFO:tensorflow:loss = 0.045405015, step = 37352 (33.941 sec)
# INFO:tensorflow:loss = 0.045405015 (33.940 sec)
# INFO:tensorflow:global_step/sec: 0.306533
# INFO:tensorflow:loss = 0.035157192, step = 37362 (32.623 sec)
# INFO:tensorflow:loss = 0.035157192 (32.623 sec)
# INFO:tensorflow:Saving checkpoints for 37367 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.29303
# INFO:tensorflow:loss = 0.059836, step = 37372 (34.126 sec)
# INFO:tensorflow:loss = 0.059836 (34.126 sec)
# INFO:tensorflow:global_step/sec: 0.305482
# INFO:tensorflow:loss = 0.039729647, step = 37382 (32.735 sec)
# INFO:tensorflow:loss = 0.039729647 (32.735 sec)
# INFO:tensorflow:global_step/sec: 0.297238
# INFO:tensorflow:loss = 0.049842797, step = 37392 (33.644 sec)
# INFO:tensorflow:loss = 0.049842797 (33.644 sec)
# INFO:tensorflow:global_step/sec: 0.309251
# INFO:tensorflow:loss = 0.050057914, step = 37402 (32.335 sec)
# INFO:tensorflow:loss = 0.050057914 (32.336 sec)
# INFO:tensorflow:global_step/sec: 0.295308
# INFO:tensorflow:loss = 0.030459251, step = 37412 (33.863 sec)
# INFO:tensorflow:loss = 0.030459251 (33.863 sec)
# INFO:tensorflow:global_step/sec: 0.294652
# INFO:tensorflow:loss = 0.05220461, step = 37422 (33.938 sec)
# INFO:tensorflow:loss = 0.05220461 (33.938 sec)
# INFO:tensorflow:global_step/sec: 0.295038
# INFO:tensorflow:loss = 0.0347459, step = 37432 (33.894 sec)
# INFO:tensorflow:loss = 0.0347459 (33.894 sec)
# INFO:tensorflow:global_step/sec: 0.293953
# INFO:tensorflow:loss = 0.060323484, step = 37442 (34.019 sec)
# INFO:tensorflow:loss = 0.060323484 (34.019 sec)
# INFO:tensorflow:global_step/sec: 0.294345
# INFO:tensorflow:loss = 0.009896101, step = 37452 (33.974 sec)
# INFO:tensorflow:loss = 0.009896101 (33.974 sec)
# INFO:tensorflow:global_step/sec: 0.318808
# INFO:tensorflow:loss = 0.00826733, step = 37462 (31.367 sec)
# INFO:tensorflow:loss = 0.00826733 (31.367 sec)
# INFO:tensorflow:global_step/sec: 0.293935
# INFO:tensorflow:loss = 0.027404265, step = 37472 (34.021 sec)
# INFO:tensorflow:loss = 0.027404265 (34.021 sec)
# INFO:tensorflow:global_step/sec: 0.296043
# INFO:tensorflow:loss = 0.020837726, step = 37482 (33.779 sec)
# INFO:tensorflow:loss = 0.020837726 (33.779 sec)
# INFO:tensorflow:global_step/sec: 0.305278
# INFO:tensorflow:loss = 0.015239371, step = 37492 (32.757 sec)
# INFO:tensorflow:loss = 0.015239371 (32.757 sec)
# INFO:tensorflow:global_step/sec: 0.306947
# INFO:tensorflow:loss = 0.03904742, step = 37502 (32.579 sec)
# INFO:tensorflow:loss = 0.03904742 (32.579 sec)
# INFO:tensorflow:global_step/sec: 0.294516
# INFO:tensorflow:loss = 0.028382184, step = 37512 (33.954 sec)
# INFO:tensorflow:loss = 0.028382184 (33.954 sec)
# INFO:tensorflow:global_step/sec: 0.307169
# INFO:tensorflow:loss = 0.02327411, step = 37522 (32.555 sec)
# INFO:tensorflow:loss = 0.02327411 (32.555 sec)
# INFO:tensorflow:global_step/sec: 0.293744
# INFO:tensorflow:loss = 0.1129559, step = 37532 (34.044 sec)
# INFO:tensorflow:loss = 0.1129559 (34.043 sec)
# INFO:tensorflow:global_step/sec: 0.295303
# INFO:tensorflow:loss = 0.017124288, step = 37542 (33.864 sec)
# INFO:tensorflow:loss = 0.017124288 (33.864 sec)
# INFO:tensorflow:Saving checkpoints for 37547 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.294708
# INFO:tensorflow:loss = 0.019539874, step = 37552 (33.932 sec)
# INFO:tensorflow:loss = 0.019539874 (33.932 sec)
# INFO:tensorflow:global_step/sec: 0.305528
# INFO:tensorflow:loss = 0.04533221, step = 37562 (32.730 sec)
# INFO:tensorflow:loss = 0.04533221 (32.730 sec)
# INFO:tensorflow:global_step/sec: 0.307401
# INFO:tensorflow:loss = 0.027844053, step = 37572 (32.531 sec)
# INFO:tensorflow:loss = 0.027844053 (32.531 sec)
# INFO:tensorflow:global_step/sec: 0.296153
# INFO:tensorflow:loss = 0.04408445, step = 37582 (33.766 sec)
# INFO:tensorflow:loss = 0.04408445 (33.766 sec)
# INFO:tensorflow:global_step/sec: 0.29663
# INFO:tensorflow:loss = 0.10637787, step = 37592 (33.712 sec)
# INFO:tensorflow:loss = 0.10637787 (33.713 sec)
# INFO:tensorflow:global_step/sec: 0.294352
# INFO:tensorflow:loss = 0.04347895, step = 37602 (33.973 sec)
# INFO:tensorflow:loss = 0.04347895 (33.973 sec)
# INFO:tensorflow:global_step/sec: 0.295105
# INFO:tensorflow:loss = 0.08928546, step = 37612 (33.886 sec)
# INFO:tensorflow:loss = 0.08928546 (33.886 sec)
# INFO:tensorflow:global_step/sec: 0.319096
# INFO:tensorflow:loss = 0.054283388, step = 37622 (31.338 sec)
# INFO:tensorflow:loss = 0.054283388 (31.338 sec)
# INFO:tensorflow:global_step/sec: 0.294831
# INFO:tensorflow:loss = 0.03744678, step = 37632 (33.918 sec)
# INFO:tensorflow:loss = 0.03744678 (33.918 sec)
# INFO:tensorflow:global_step/sec: 0.294029
# INFO:tensorflow:loss = 0.01705519, step = 37642 (34.010 sec)
# INFO:tensorflow:loss = 0.01705519 (34.010 sec)
# INFO:tensorflow:global_step/sec: 0.294442
# INFO:tensorflow:loss = 0.028844863, step = 37652 (33.963 sec)
# INFO:tensorflow:loss = 0.028844863 (33.963 sec)
# INFO:tensorflow:global_step/sec: 0.295246
# INFO:tensorflow:loss = 0.062803775, step = 37662 (33.870 sec)
# INFO:tensorflow:loss = 0.062803775 (33.870 sec)
# INFO:tensorflow:global_step/sec: 0.294334
# INFO:tensorflow:loss = 0.01942212, step = 37672 (33.975 sec)
# INFO:tensorflow:loss = 0.01942212 (33.975 sec)
# INFO:tensorflow:global_step/sec: 0.294052
# INFO:tensorflow:loss = 0.007740664, step = 37682 (34.007 sec)
# INFO:tensorflow:loss = 0.007740664 (34.007 sec)
# INFO:tensorflow:global_step/sec: 0.295686
# INFO:tensorflow:loss = 0.006213132, step = 37692 (33.820 sec)
# INFO:tensorflow:loss = 0.006213132 (33.820 sec)
# INFO:tensorflow:global_step/sec: 0.306552
# INFO:tensorflow:loss = 0.023520716, step = 37702 (32.621 sec)
# INFO:tensorflow:loss = 0.023520716 (32.621 sec)
# INFO:tensorflow:global_step/sec: 0.295548
# INFO:tensorflow:loss = 0.021599604, step = 37712 (33.835 sec)
# INFO:tensorflow:loss = 0.021599604 (33.835 sec)
# INFO:tensorflow:global_step/sec: 0.305872
# INFO:tensorflow:loss = 0.032888878, step = 37722 (32.693 sec)
# INFO:tensorflow:loss = 0.032888878 (32.694 sec)
# INFO:tensorflow:Saving checkpoints for 37727 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.305695
# INFO:tensorflow:loss = 0.037035063, step = 37732 (32.713 sec)
# INFO:tensorflow:loss = 0.037035063 (32.713 sec)
# INFO:tensorflow:global_step/sec: 0.294148
# INFO:tensorflow:loss = 0.033616796, step = 37742 (33.996 sec)
# INFO:tensorflow:loss = 0.033616796 (33.996 sec)
# INFO:tensorflow:global_step/sec: 0.296784
# INFO:tensorflow:loss = 0.020654855, step = 37752 (33.695 sec)
# INFO:tensorflow:loss = 0.020654855 (33.694 sec)
# INFO:tensorflow:global_step/sec: 0.294611
# INFO:tensorflow:loss = 0.028728107, step = 37762 (33.943 sec)
# INFO:tensorflow:loss = 0.028728107 (33.943 sec)
# INFO:tensorflow:global_step/sec: 0.298095
# INFO:tensorflow:loss = 0.030392848, step = 37772 (33.546 sec)
# INFO:tensorflow:loss = 0.030392848 (33.546 sec)
# INFO:tensorflow:global_step/sec: 0.29755
# INFO:tensorflow:loss = 0.029728845, step = 37782 (33.608 sec)
# INFO:tensorflow:loss = 0.029728845 (33.608 sec)
# INFO:tensorflow:global_step/sec: 0.295364
# INFO:tensorflow:loss = 0.044672947, step = 37792 (33.856 sec)
# INFO:tensorflow:loss = 0.044672947 (33.857 sec)
# INFO:tensorflow:global_step/sec: 0.295921
# INFO:tensorflow:loss = 0.024954991, step = 37802 (33.793 sec)
# INFO:tensorflow:loss = 0.024954991 (33.793 sec)
# INFO:tensorflow:global_step/sec: 0.295894
# INFO:tensorflow:loss = 0.07239276, step = 37812 (33.796 sec)
# INFO:tensorflow:loss = 0.07239276 (33.796 sec)
# INFO:tensorflow:global_step/sec: 0.295594
# INFO:tensorflow:loss = 0.065479666, step = 37822 (33.830 sec)
# INFO:tensorflow:loss = 0.065479666 (33.830 sec)
# INFO:tensorflow:global_step/sec: 0.295128
# INFO:tensorflow:loss = 0.045722626, step = 37832 (33.884 sec)
# INFO:tensorflow:loss = 0.045722626 (33.884 sec)
# INFO:tensorflow:global_step/sec: 0.294748
# INFO:tensorflow:loss = 0.028719623, step = 37842 (33.927 sec)
# INFO:tensorflow:loss = 0.028719623 (33.927 sec)
# INFO:tensorflow:global_step/sec: 0.295491
# INFO:tensorflow:loss = 0.0140690645, step = 37852 (33.842 sec)
# INFO:tensorflow:loss = 0.0140690645 (33.842 sec)
# INFO:tensorflow:global_step/sec: 0.306022
# INFO:tensorflow:loss = 0.022839045, step = 37862 (32.677 sec)
# INFO:tensorflow:loss = 0.022839045 (32.677 sec)
# INFO:tensorflow:global_step/sec: 0.29565
# INFO:tensorflow:loss = 0.03549864, step = 37872 (33.824 sec)
# INFO:tensorflow:loss = 0.03549864 (33.824 sec)
# INFO:tensorflow:global_step/sec: 0.295379
# INFO:tensorflow:loss = 0.07354094, step = 37882 (33.855 sec)
# INFO:tensorflow:loss = 0.07354094 (33.855 sec)
# INFO:tensorflow:global_step/sec: 0.295205
# INFO:tensorflow:loss = 0.05512563, step = 37892 (33.875 sec)
# INFO:tensorflow:loss = 0.05512563 (33.875 sec)
# INFO:tensorflow:global_step/sec: 0.317122
# INFO:tensorflow:loss = 0.01861625, step = 37902 (31.534 sec)
# INFO:tensorflow:loss = 0.01861625 (31.534 sec)
# INFO:tensorflow:Saving checkpoints for 37906 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.29303
# INFO:tensorflow:loss = 0.04751632, step = 37912 (34.126 sec)
# INFO:tensorflow:loss = 0.04751632 (34.126 sec)
# INFO:tensorflow:global_step/sec: 0.307414
# INFO:tensorflow:loss = 0.017765759, step = 37922 (32.529 sec)
# INFO:tensorflow:loss = 0.017765759 (32.530 sec)
# INFO:tensorflow:global_step/sec: 0.305462
# INFO:tensorflow:loss = 0.050579496, step = 37932 (32.737 sec)
# INFO:tensorflow:loss = 0.050579496 (32.737 sec)
# INFO:tensorflow:global_step/sec: 0.306852
# INFO:tensorflow:loss = 0.024774812, step = 37942 (32.589 sec)
# INFO:tensorflow:loss = 0.024774812 (32.589 sec)
# INFO:tensorflow:global_step/sec: 0.294407
# INFO:tensorflow:loss = 0.015959863, step = 37952 (33.967 sec)
# INFO:tensorflow:loss = 0.015959863 (33.966 sec)
# INFO:tensorflow:global_step/sec: 0.299974
# INFO:tensorflow:loss = 0.044110678, step = 37962 (33.336 sec)
# INFO:tensorflow:loss = 0.044110678 (33.336 sec)
# INFO:tensorflow:global_step/sec: 0.295123
# INFO:tensorflow:loss = 0.1065689, step = 37972 (33.884 sec)
# INFO:tensorflow:loss = 0.1065689 (33.885 sec)
# INFO:tensorflow:global_step/sec: 0.307441
# INFO:tensorflow:loss = 0.049236827, step = 37982 (32.526 sec)
# INFO:tensorflow:loss = 0.049236827 (32.527 sec)
# INFO:tensorflow:global_step/sec: 0.29457
# INFO:tensorflow:loss = 0.060709976, step = 37992 (33.948 sec)
# INFO:tensorflow:loss = 0.060709976 (33.948 sec)
# INFO:tensorflow:global_step/sec: 0.294937
# INFO:tensorflow:loss = 0.020502586, step = 38002 (33.906 sec)
# INFO:tensorflow:loss = 0.020502586 (33.906 sec)
# INFO:tensorflow:global_step/sec: 0.296409
# INFO:tensorflow:loss = 0.03831748, step = 38012 (33.737 sec)
# INFO:tensorflow:loss = 0.03831748 (33.737 sec)
# INFO:tensorflow:global_step/sec: 0.295261
# INFO:tensorflow:loss = 0.05229173, step = 38022 (33.868 sec)
# INFO:tensorflow:loss = 0.05229173 (33.868 sec)
# INFO:tensorflow:global_step/sec: 0.295476
# INFO:tensorflow:loss = 0.012274237, step = 38032 (33.844 sec)
# INFO:tensorflow:loss = 0.012274237 (33.844 sec)
# INFO:tensorflow:global_step/sec: 0.29537
# INFO:tensorflow:loss = 0.035675026, step = 38042 (33.856 sec)
# INFO:tensorflow:loss = 0.035675026 (33.856 sec)
# INFO:tensorflow:global_step/sec: 0.295889
# INFO:tensorflow:loss = 0.060450785, step = 38052 (33.796 sec)
# INFO:tensorflow:loss = 0.060450785 (33.796 sec)
# INFO:tensorflow:global_step/sec: 0.29503
# INFO:tensorflow:loss = 0.016109172, step = 38062 (33.895 sec)
# INFO:tensorflow:loss = 0.016109172 (33.895 sec)
# INFO:tensorflow:global_step/sec: 0.294711
# INFO:tensorflow:loss = 0.08052705, step = 38072 (33.932 sec)
# INFO:tensorflow:loss = 0.08052705 (33.932 sec)
# INFO:tensorflow:global_step/sec: 0.307285
# INFO:tensorflow:loss = 0.050826624, step = 38082 (32.543 sec)
# INFO:tensorflow:loss = 0.050826624 (32.543 sec)
# INFO:tensorflow:Saving checkpoints for 38086 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.29391
# INFO:tensorflow:loss = 0.064418845, step = 38092 (34.024 sec)
# INFO:tensorflow:loss = 0.064418845 (34.024 sec)
# INFO:tensorflow:global_step/sec: 0.296114
# INFO:tensorflow:loss = 0.027993958, step = 38102 (33.771 sec)
# INFO:tensorflow:loss = 0.027993958 (33.771 sec)
# INFO:tensorflow:global_step/sec: 0.306063
# INFO:tensorflow:loss = 0.037183184, step = 38112 (32.673 sec)
# INFO:tensorflow:loss = 0.037183184 (32.673 sec)
# INFO:tensorflow:global_step/sec: 0.295374
# INFO:tensorflow:loss = 0.03456683, step = 38122 (33.855 sec)
# INFO:tensorflow:loss = 0.03456683 (33.855 sec)
# INFO:tensorflow:global_step/sec: 0.294838
# INFO:tensorflow:loss = 0.014037082, step = 38132 (33.917 sec)
# INFO:tensorflow:loss = 0.014037082 (33.917 sec)
# INFO:tensorflow:global_step/sec: 0.294907
# INFO:tensorflow:loss = 0.027616676, step = 38142 (33.909 sec)
# INFO:tensorflow:loss = 0.027616676 (33.909 sec)
# INFO:tensorflow:global_step/sec: 0.300967
# INFO:tensorflow:loss = 0.0659792, step = 38152 (33.226 sec)
# INFO:tensorflow:loss = 0.0659792 (33.226 sec)
# INFO:tensorflow:global_step/sec: 0.295567
# INFO:tensorflow:loss = 0.022502962, step = 38162 (33.833 sec)
# INFO:tensorflow:loss = 0.022502962 (33.833 sec)
# INFO:tensorflow:global_step/sec: 0.295641
# INFO:tensorflow:loss = 0.021536415, step = 38172 (33.825 sec)
# INFO:tensorflow:loss = 0.021536415 (33.825 sec)
# INFO:tensorflow:global_step/sec: 0.295242
# INFO:tensorflow:loss = 0.011493122, step = 38182 (33.871 sec)
# INFO:tensorflow:loss = 0.011493122 (33.871 sec)
# INFO:tensorflow:global_step/sec: 0.306887
# INFO:tensorflow:loss = 0.01476234, step = 38192 (32.585 sec)
# INFO:tensorflow:loss = 0.01476234 (32.585 sec)
# INFO:tensorflow:global_step/sec: 0.330687
# INFO:tensorflow:loss = 0.031260565, step = 38202 (30.240 sec)
# INFO:tensorflow:loss = 0.031260565 (30.240 sec)
# INFO:tensorflow:global_step/sec: 0.295553
# INFO:tensorflow:loss = 0.038832366, step = 38212 (33.835 sec)
# INFO:tensorflow:loss = 0.038832366 (33.835 sec)
# INFO:tensorflow:global_step/sec: 0.294852
# INFO:tensorflow:loss = 0.0114522735, step = 38222 (33.915 sec)
# INFO:tensorflow:loss = 0.0114522735 (33.915 sec)
# INFO:tensorflow:global_step/sec: 0.294843
# INFO:tensorflow:loss = 0.03470111, step = 38232 (33.916 sec)
# INFO:tensorflow:loss = 0.03470111 (33.916 sec)
# INFO:tensorflow:global_step/sec: 0.295203
# INFO:tensorflow:loss = 0.021926733, step = 38242 (33.875 sec)
# INFO:tensorflow:loss = 0.021926733 (33.875 sec)
# INFO:tensorflow:global_step/sec: 0.305656
# INFO:tensorflow:loss = 0.012074782, step = 38252 (32.717 sec)
# INFO:tensorflow:loss = 0.012074782 (32.717 sec)
# INFO:tensorflow:global_step/sec: 0.29622
# INFO:tensorflow:loss = 0.0519827, step = 38262 (33.759 sec)
# INFO:tensorflow:loss = 0.0519827 (33.759 sec)
# INFO:tensorflow:Saving checkpoints for 38266 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.304918
# INFO:tensorflow:loss = 0.040103327, step = 38272 (32.795 sec)
# INFO:tensorflow:loss = 0.040103327 (32.795 sec)
# INFO:tensorflow:global_step/sec: 0.306943
# INFO:tensorflow:loss = 0.01035242, step = 38282 (32.580 sec)
# INFO:tensorflow:loss = 0.01035242 (32.579 sec)
# INFO:tensorflow:global_step/sec: 0.295607
# INFO:tensorflow:loss = 0.0385529, step = 38292 (33.829 sec)
# INFO:tensorflow:loss = 0.0385529 (33.829 sec)
# INFO:tensorflow:global_step/sec: 0.295668
# INFO:tensorflow:loss = 0.12548995, step = 38302 (33.822 sec)
# INFO:tensorflow:loss = 0.12548995 (33.822 sec)
# INFO:tensorflow:global_step/sec: 0.306063
# INFO:tensorflow:loss = 0.009141454, step = 38312 (32.673 sec)
# INFO:tensorflow:loss = 0.009141454 (32.673 sec)
# INFO:tensorflow:global_step/sec: 0.306732
# INFO:tensorflow:loss = 0.02897375, step = 38322 (32.602 sec)
# INFO:tensorflow:loss = 0.02897375 (32.602 sec)
# INFO:tensorflow:global_step/sec: 0.296744
# INFO:tensorflow:loss = 0.06056828, step = 38332 (33.699 sec)
# INFO:tensorflow:loss = 0.06056828 (33.699 sec)
# INFO:tensorflow:global_step/sec: 0.298929
# INFO:tensorflow:loss = 0.00965623, step = 38342 (33.453 sec)
# INFO:tensorflow:loss = 0.00965623 (33.453 sec)
# INFO:tensorflow:global_step/sec: 0.307347
# INFO:tensorflow:loss = 0.03933412, step = 38352 (32.537 sec)
# INFO:tensorflow:loss = 0.03933412 (32.537 sec)
# INFO:tensorflow:global_step/sec: 0.295526
# INFO:tensorflow:loss = 0.04688299, step = 38362 (33.837 sec)
# INFO:tensorflow:loss = 0.04688299 (33.837 sec)
# INFO:tensorflow:global_step/sec: 0.31904
# INFO:tensorflow:loss = 0.036289703, step = 38372 (31.344 sec)
# INFO:tensorflow:loss = 0.036289703 (31.344 sec)
# INFO:tensorflow:global_step/sec: 0.319448
# INFO:tensorflow:loss = 0.0421176, step = 38382 (31.304 sec)
# INFO:tensorflow:loss = 0.0421176 (31.304 sec)
# INFO:tensorflow:global_step/sec: 0.29481
# INFO:tensorflow:loss = 0.054594245, step = 38392 (33.920 sec)
# INFO:tensorflow:loss = 0.054594245 (33.920 sec)
# INFO:tensorflow:global_step/sec: 0.306638
# INFO:tensorflow:loss = 0.020573812, step = 38402 (32.612 sec)
# INFO:tensorflow:loss = 0.020573812 (32.612 sec)
# INFO:tensorflow:global_step/sec: 0.3053
# INFO:tensorflow:loss = 0.019576058, step = 38412 (32.755 sec)
# INFO:tensorflow:loss = 0.019576058 (32.755 sec)
# INFO:tensorflow:global_step/sec: 0.296079
# INFO:tensorflow:loss = 0.011544979, step = 38422 (33.775 sec)
# INFO:tensorflow:loss = 0.011544979 (33.775 sec)
# INFO:tensorflow:global_step/sec: 0.306462
# INFO:tensorflow:loss = 0.0039332, step = 38432 (32.630 sec)
# INFO:tensorflow:loss = 0.0039332 (32.630 sec)
# INFO:tensorflow:global_step/sec: 0.306749
# INFO:tensorflow:loss = 0.059354305, step = 38442 (32.600 sec)
# INFO:tensorflow:loss = 0.059354305 (32.600 sec)
# INFO:tensorflow:Saving checkpoints for 38448 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.293299
# INFO:tensorflow:loss = 0.043068808, step = 38452 (34.095 sec)
# INFO:tensorflow:loss = 0.043068808 (34.095 sec)
# INFO:tensorflow:global_step/sec: 0.305976
# INFO:tensorflow:loss = 0.052432474, step = 38462 (32.682 sec)
# INFO:tensorflow:loss = 0.052432474 (32.682 sec)
# INFO:tensorflow:global_step/sec: 0.295043
# INFO:tensorflow:loss = 0.008849413, step = 38472 (33.893 sec)
# INFO:tensorflow:loss = 0.008849413 (33.893 sec)
# INFO:tensorflow:global_step/sec: 0.294497
# INFO:tensorflow:loss = 0.046397116, step = 38482 (33.956 sec)
# INFO:tensorflow:loss = 0.046397116 (33.956 sec)
# INFO:tensorflow:global_step/sec: 0.30705
# INFO:tensorflow:loss = 0.023384668, step = 38492 (32.568 sec)
# INFO:tensorflow:loss = 0.023384668 (32.568 sec)
# INFO:tensorflow:global_step/sec: 0.294255
# INFO:tensorflow:loss = 0.07485601, step = 38502 (33.984 sec)
# INFO:tensorflow:loss = 0.07485601 (33.984 sec)
# INFO:tensorflow:global_step/sec: 0.307436
# INFO:tensorflow:loss = 0.020023126, step = 38512 (32.527 sec)
# INFO:tensorflow:loss = 0.020023126 (32.527 sec)
# INFO:tensorflow:global_step/sec: 0.29539
# INFO:tensorflow:loss = 0.043862965, step = 38522 (33.854 sec)
# INFO:tensorflow:loss = 0.043862965 (33.854 sec)
# INFO:tensorflow:global_step/sec: 0.298301
# INFO:tensorflow:loss = 0.079898976, step = 38532 (33.523 sec)
# INFO:tensorflow:loss = 0.079898976 (33.523 sec)
# INFO:tensorflow:global_step/sec: 0.306866
# INFO:tensorflow:loss = 0.029600553, step = 38542 (32.587 sec)
# INFO:tensorflow:loss = 0.029600553 (32.587 sec)
# INFO:tensorflow:global_step/sec: 0.294741
# INFO:tensorflow:loss = 0.06272733, step = 38552 (33.928 sec)
# INFO:tensorflow:loss = 0.06272733 (33.928 sec)
# INFO:tensorflow:global_step/sec: 0.29565
# INFO:tensorflow:loss = 0.040320955, step = 38562 (33.824 sec)
# INFO:tensorflow:loss = 0.040320955 (33.824 sec)
# INFO:tensorflow:global_step/sec: 0.295368
# INFO:tensorflow:loss = 0.020993352, step = 38572 (33.856 sec)
# INFO:tensorflow:loss = 0.020993352 (33.856 sec)
# INFO:tensorflow:global_step/sec: 0.31862
# INFO:tensorflow:loss = 0.06999457, step = 38582 (31.385 sec)
# INFO:tensorflow:loss = 0.06999457 (31.385 sec)
# INFO:tensorflow:global_step/sec: 0.294508
# INFO:tensorflow:loss = 0.02970434, step = 38592 (33.955 sec)
# INFO:tensorflow:loss = 0.02970434 (33.955 sec)
# INFO:tensorflow:global_step/sec: 0.31843
# INFO:tensorflow:loss = 0.016333982, step = 38602 (31.404 sec)
# INFO:tensorflow:loss = 0.016333982 (31.404 sec)
# INFO:tensorflow:global_step/sec: 0.296989
# INFO:tensorflow:loss = 0.06522296, step = 38612 (33.671 sec)
# INFO:tensorflow:loss = 0.06522296 (33.671 sec)
# INFO:tensorflow:global_step/sec: 0.295479
# INFO:tensorflow:loss = 0.023418762, step = 38622 (33.843 sec)
# INFO:tensorflow:loss = 0.023418762 (33.843 sec)
# INFO:tensorflow:Saving checkpoints for 38629 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.306102
# INFO:tensorflow:loss = 0.022623152, step = 38632 (32.669 sec)
# INFO:tensorflow:loss = 0.022623152 (32.669 sec)
# INFO:tensorflow:global_step/sec: 0.295085
# INFO:tensorflow:loss = 0.070359185, step = 38642 (33.888 sec)
# INFO:tensorflow:loss = 0.070359185 (33.889 sec)
# INFO:tensorflow:global_step/sec: 0.306223
# INFO:tensorflow:loss = 0.022803906, step = 38652 (32.656 sec)
# INFO:tensorflow:loss = 0.022803906 (32.656 sec)
# INFO:tensorflow:global_step/sec: 0.305892
# INFO:tensorflow:loss = 0.029735336, step = 38662 (32.691 sec)
# INFO:tensorflow:loss = 0.029735336 (32.692 sec)
# INFO:tensorflow:global_step/sec: 0.296233
# INFO:tensorflow:loss = 0.009054987, step = 38672 (33.757 sec)
# INFO:tensorflow:loss = 0.009054987 (33.757 sec)
# INFO:tensorflow:global_step/sec: 0.294664
# INFO:tensorflow:loss = 0.07990575, step = 38682 (33.937 sec)
# INFO:tensorflow:loss = 0.07990575 (33.937 sec)
# INFO:tensorflow:global_step/sec: 0.306239
# INFO:tensorflow:loss = 0.040705826, step = 38692 (32.654 sec)
# INFO:tensorflow:loss = 0.040705826 (32.654 sec)
# INFO:tensorflow:global_step/sec: 0.307377
# INFO:tensorflow:loss = 0.07088897, step = 38702 (32.533 sec)
# INFO:tensorflow:loss = 0.07088897 (32.534 sec)
# INFO:tensorflow:global_step/sec: 0.295067
# INFO:tensorflow:loss = 0.038786877, step = 38712 (33.891 sec)
# INFO:tensorflow:loss = 0.038786877 (33.890 sec)
# INFO:tensorflow:global_step/sec: 0.300586
# INFO:tensorflow:loss = 0.046435174, step = 38722 (33.268 sec)
# INFO:tensorflow:loss = 0.046435174 (33.268 sec)
# INFO:tensorflow:global_step/sec: 0.295403
# INFO:tensorflow:loss = 0.03361639, step = 38732 (33.852 sec)
# INFO:tensorflow:loss = 0.03361639 (33.852 sec)
# INFO:tensorflow:global_step/sec: 0.296103
# INFO:tensorflow:loss = 0.0063144844, step = 38742 (33.772 sec)
# INFO:tensorflow:loss = 0.0063144844 (33.772 sec)
# INFO:tensorflow:global_step/sec: 0.305333
# INFO:tensorflow:loss = 0.045628108, step = 38752 (32.752 sec)
# INFO:tensorflow:loss = 0.045628108 (32.752 sec)
# INFO:tensorflow:global_step/sec: 0.295488
# INFO:tensorflow:loss = 0.038178854, step = 38762 (33.841 sec)
# INFO:tensorflow:loss = 0.038178854 (33.842 sec)
# INFO:tensorflow:loss = 0.026562413, step = 38792 (33.857 sec)
# INFO:tensorflow:loss = 0.026562413 (33.857 sec)
# INFO:tensorflow:global_step/sec: 0.294428
# INFO:tensorflow:loss = 0.0152335195, step = 38802 (33.964 sec)
# INFO:tensorflow:loss = 0.0152335195 (33.964 sec)
# INFO:tensorflow:Saving checkpoints for 38810 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.305621
# INFO:tensorflow:loss = 0.031108744, step = 38812 (32.720 sec)
# INFO:tensorflow:loss = 0.031108744 (32.720 sec)
# INFO:tensorflow:global_step/sec: 0.317303
# INFO:tensorflow:loss = 0.08966313, step = 38822 (31.516 sec)
# INFO:tensorflow:loss = 0.08966313 (31.516 sec)
# INFO:tensorflow:global_step/sec: 0.29516
# INFO:tensorflow:loss = 0.024994606, step = 38832 (33.880 sec)
# INFO:tensorflow:loss = 0.024994606 (33.880 sec)
# INFO:tensorflow:global_step/sec: 0.295397
# INFO:tensorflow:loss = 0.06619309, step = 38842 (33.853 sec)
# INFO:tensorflow:loss = 0.06619309 (33.853 sec)
# INFO:tensorflow:global_step/sec: 0.295826
# INFO:tensorflow:loss = 0.015166354, step = 38852 (33.804 sec)
# INFO:tensorflow:loss = 0.015166354 (33.804 sec)
# INFO:tensorflow:global_step/sec: 0.29704
# INFO:tensorflow:loss = 0.07397752, step = 38862 (33.665 sec)
# INFO:tensorflow:loss = 0.07397752 (33.665 sec)
# INFO:tensorflow:global_step/sec: 0.305769
# INFO:tensorflow:loss = 0.062896244, step = 38872 (32.704 sec)
# INFO:tensorflow:loss = 0.062896244 (32.704 sec)
# INFO:tensorflow:global_step/sec: 0.319677
# INFO:tensorflow:loss = 0.063908756, step = 38882 (31.281 sec)
# INFO:tensorflow:loss = 0.063908756 (31.281 sec)
# INFO:tensorflow:global_step/sec: 0.294086
# INFO:tensorflow:loss = 0.0414273, step = 38892 (34.004 sec)
# INFO:tensorflow:loss = 0.0414273 (34.004 sec)
# INFO:tensorflow:global_step/sec: 0.307753
# INFO:tensorflow:loss = 0.063667126, step = 38902 (32.493 sec)
# INFO:tensorflow:loss = 0.063667126 (32.493 sec)
# INFO:tensorflow:global_step/sec: 0.299115
# INFO:tensorflow:loss = 0.027164407, step = 38912 (33.432 sec)
# INFO:tensorflow:loss = 0.027164407 (33.432 sec)
# INFO:tensorflow:global_step/sec: 0.294964
# INFO:tensorflow:loss = 0.06648123, step = 38922 (33.902 sec)
# INFO:tensorflow:loss = 0.06648123 (33.902 sec)
# INFO:tensorflow:global_step/sec: 0.319363
# INFO:tensorflow:loss = 0.023630189, step = 38932 (31.312 sec)
# INFO:tensorflow:loss = 0.023630189 (31.312 sec)
# INFO:tensorflow:global_step/sec: 0.295505
# INFO:tensorflow:loss = 0.008874157, step = 38942 (33.840 sec)
# INFO:tensorflow:loss = 0.008874157 (33.840 sec)
# INFO:tensorflow:global_step/sec: 0.307431
# INFO:tensorflow:loss = 0.034273125, step = 38952 (32.528 sec)
# INFO:tensorflow:loss = 0.034273125 (32.527 sec)
# INFO:tensorflow:global_step/sec: 0.294925
# INFO:tensorflow:loss = 0.042593844, step = 38962 (33.907 sec)
# INFO:tensorflow:loss = 0.042593844 (33.907 sec)
# INFO:tensorflow:global_step/sec: 0.296068
# INFO:tensorflow:loss = 0.017448328, step = 38972 (33.776 sec)
# INFO:tensorflow:loss = 0.017448328 (33.777 sec)
# INFO:tensorflow:global_step/sec: 0.29412
# INFO:tensorflow:loss = 0.07383825, step = 38982 (34.000 sec)
# INFO:tensorflow:loss = 0.07383825 (33.999 sec)
# INFO:tensorflow:Saving checkpoints for 38991 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.305262
# INFO:tensorflow:loss = 0.01647509, step = 38992 (32.758 sec)
# INFO:tensorflow:loss = 0.01647509 (32.758 sec)
# INFO:tensorflow:global_step/sec: 0.295699
# INFO:tensorflow:loss = 0.01834921, step = 39002 (33.818 sec)
# INFO:tensorflow:loss = 0.01834921 (33.818 sec)
# INFO:tensorflow:global_step/sec: 0.305827
# INFO:tensorflow:loss = 0.051142704, step = 39012 (32.698 sec)
# INFO:tensorflow:loss = 0.051142704 (32.698 sec)
# INFO:tensorflow:global_step/sec: 0.305493
# INFO:tensorflow:loss = 0.054308094, step = 39022 (32.734 sec)
# INFO:tensorflow:loss = 0.054308094 (32.734 sec)
# INFO:tensorflow:global_step/sec: 0.293054
# INFO:tensorflow:loss = 0.02252661, step = 39032 (34.124 sec)
# INFO:tensorflow:loss = 0.02252661 (34.124 sec)
# INFO:tensorflow:global_step/sec: 0.293659
# INFO:tensorflow:loss = 0.023427658, step = 39042 (34.053 sec)
# INFO:tensorflow:loss = 0.023427658 (34.053 sec)
# INFO:tensorflow:global_step/sec: 0.292855
# INFO:tensorflow:loss = 0.042719208, step = 39052 (34.147 sec)
# INFO:tensorflow:loss = 0.042719208 (34.147 sec)
# INFO:tensorflow:global_step/sec: 0.292809
# INFO:tensorflow:loss = 0.03798379, step = 39062 (34.152 sec)
# INFO:tensorflow:loss = 0.03798379 (34.152 sec)
# INFO:tensorflow:global_step/sec: 0.305284
# INFO:tensorflow:loss = 0.0140160145, step = 39072 (32.756 sec)
# INFO:tensorflow:loss = 0.0140160145 (32.756 sec)
# INFO:tensorflow:global_step/sec: 0.293952
# INFO:tensorflow:loss = 0.012919905, step = 39082 (34.019 sec)
# INFO:tensorflow:loss = 0.012919905 (34.019 sec)
# INFO:tensorflow:global_step/sec: 0.297683
# INFO:tensorflow:loss = 0.0029342207, step = 39092 (33.593 sec)
# INFO:tensorflow:loss = 0.0029342207 (33.593 sec)
# INFO:tensorflow:global_step/sec: 0.296839
# INFO:tensorflow:loss = 0.027942844, step = 39102 (33.688 sec)
# INFO:tensorflow:loss = 0.027942844 (33.688 sec)
# INFO:tensorflow:global_step/sec: 0.295076
# INFO:tensorflow:loss = 0.012465144, step = 39112 (33.890 sec)
# INFO:tensorflow:loss = 0.012465144 (33.890 sec)
# INFO:tensorflow:global_step/sec: 0.295125
# INFO:tensorflow:loss = 0.035339557, step = 39122 (33.884 sec)
# INFO:tensorflow:loss = 0.035339557 (33.884 sec)
# INFO:tensorflow:global_step/sec: 0.29433
# INFO:tensorflow:loss = 0.0768482, step = 39132 (33.976 sec)
# INFO:tensorflow:loss = 0.0768482 (33.976 sec)
# INFO:tensorflow:global_step/sec: 0.293703
# INFO:tensorflow:loss = 0.029619811, step = 39142 (34.048 sec)
# INFO:tensorflow:loss = 0.029619811 (34.048 sec)
# INFO:tensorflow:global_step/sec: 0.294721
# INFO:tensorflow:loss = 0.02509535, step = 39152 (33.930 sec)
# INFO:tensorflow:loss = 0.02509535 (33.930 sec)
# INFO:tensorflow:global_step/sec: 0.296373
# INFO:tensorflow:loss = 0.06035604, step = 39162 (33.741 sec)
# INFO:tensorflow:loss = 0.06035604 (33.741 sec)
# INFO:tensorflow:Saving checkpoints for 39170 into /home/ec2-user/convnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.304757
# INFO:tensorflow:loss = 0.013751683, step = 39172 (32.813 sec)
# INFO:tensorflow:loss = 0.013751683 (32.813 sec)
# INFO:tensorflow:global_step/sec: 0.308088
# INFO:tensorflow:loss = 0.01703914, step = 39182 (32.458 sec)
# INFO:tensorflow:loss = 0.01703914 (32.458 sec)
# INFO:tensorflow:global_step/sec: 0.318311
# INFO:tensorflow:loss = 0.05293221, step = 39192 (31.416 sec)
# INFO:tensorflow:loss = 0.05293221 (31.416 sec)
# INFO:tensorflow:global_step/sec: 0.319598
# INFO:tensorflow:loss = 0.01469591, step = 39202 (31.289 sec)
# INFO:tensorflow:loss = 0.01469591 (31.289 sec)
# INFO:tensorflow:global_step/sec: 0.306323
# INFO:tensorflow:loss = 0.03891771, step = 39212 (32.645 sec)
# INFO:tensorflow:loss = 0.03891771 (32.645 sec)
# INFO:tensorflow:global_step/sec: 0.306234
# INFO:tensorflow:loss = 0.039338708, step = 39222 (32.655 sec)
# INFO:tensorflow:loss = 0.039338708 (32.655 sec)
# INFO:tensorflow:global_step/sec: 0.296946
# INFO:tensorflow:loss = 0.022623673, step = 39232 (33.676 sec)
# INFO:tensorflow:loss = 0.022623673 (33.676 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6d6a4319b91e> in <module>
#       1 car_classifier.train(
#       2       input_fn=lambda:image_processor_train_input_fn(training_image_processor, X_train, y_train, 128),
# ----> 3       steps=90000
#       4     )
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1157                                              hooks, global_step_tensor,
# -> 1158                                              saving_listeners)
#    1159
#    1160   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1405       any_step_done = False
#    1406       while not mon_sess.should_stop():
# -> 1407         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1408         any_step_done = True
#    1409     if not any_step_done:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     674                           feed_dict=feed_dict,
#     675                           options=options,
# --> 676                           run_metadata=run_metadata)
#     677
#     678   def run_step_fn(self, step_fn):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1169                               feed_dict=feed_dict,
#    1170                               options=options,
# -> 1171                               run_metadata=run_metadata)
#    1172       except _PREEMPTION_ERRORS as e:
#    1173         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1253   def run(self, *args, **kwargs):
#    1254     try:
# -> 1255       return self._sess.run(*args, **kwargs)
#    1256     except _PREEMPTION_ERRORS:
#    1257       raise
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1325                                   feed_dict=feed_dict,
#    1326                                   options=options,
# -> 1327                                   run_metadata=run_metadata)
#    1328
#    1329     for hook in self._hooks:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1089
#    1090   def run(self, *args, **kwargs):
# -> 1091     return self._sess.run(*args, **kwargs)
#    1092
#    1093   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Evaluate Performance

# %%
print('training error')
eval_results = car_classifier.evaluate(
    input_fn=lambda:image_processor_eval_input_fn(testing_image_processor, X_train, y_train, 32))
print(eval_results)

print('testing error')
eval_results = car_classifier.evaluate(
    input_fn=lambda:image_processor_eval_input_fn(testing_image_processor, X_test, y_test, 32))
print(eval_results)
# Out:
# training error
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-17T00:12:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-39170
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-17-00:12:58
# INFO:tensorflow:Saving dict for global step 39170: eval_accuracy = 0.70128083, global_step = 39170, loss = 541.7264
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39170: /home/ec2-user/convnet_model/model.ckpt-39170
# {'eval_accuracy': 0.70128083, 'loss': 541.7264, 'global_step': 39170}
# testing error
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-17T00:13:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-39170
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-17-00:13:13
# INFO:tensorflow:Saving dict for global step 39170: eval_accuracy = 0.6774194, global_step = 39170, loss = 721.17065
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39170: /home/ec2-user/convnet_model/model.ckpt-39170
# {'eval_accuracy': 0.6774194, 'loss': 721.17065, 'global_step': 39170}

# %% [markdown]
# Run inference

# %%
predicted_classes = car_classifier.predict(
    input_fn=lambda:image_processor_eval_input_fn(testing_image_processor, X_test, y_test, 32))

testing_analysis = []

for pred, label in zip(predicted_classes, y_test):
    hold = [pred['probabilities'][1], pred['classes'], label[1], pred['logits'][0], pred['logits'][1]]
    testing_analysis.append(hold)
    
testing_analysis = pd.DataFrame(testing_analysis, columns = ['prob', 'class', 'label', 'logit_0', 'logit_1'])
testing_analysis['logit_1_decile'] = pd.qcut(testing_analysis.logit_1, 10, labels = False)
testing_analysis['logit_0_decile'] = pd.qcut(testing_analysis.logit_0, 10, labels = False)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-33306
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
testing_analysis.groupby(['logit_1_decile', 'label'])['class'].value_counts()
# Out:
# logit_1_decile  label  class
# 0               0      0        92
#                 1      0        17
# 1               0      0        77
#                        1         1
#                 1      0        28
#                        1         2
# 2               0      1        38
#                        0        24
#                 1      1        36
#                        0        11
# 3               0      1        61
#                 1      1        47
# 4               0      1        51
#                 1      1        58
# 5               0      1        40
#                 1      1        68
# 6               0      1        23
#                 1      1        85
# 7               0      1        25
#                 1      1        84
# 8               0      1        11
#                 1      1        97
# 9               0      1        13
#                 1      1        96
# Name: class, dtype: int64

# %%
testing_analysis.groupby(['logit_0_decile', 'label'])['class'].value_counts()
# Out:
# logit_0_decile  label  class
# 0               0      1        12
#                 1      1        97
# 1               0      1        13
#                 1      1        95
# 2               0      1        19
#                 1      1        90
# 3               0      1        35
#                 1      1        73
# 4               0      1        33
#                 1      1        76
# 5               0      1        46
#                 1      1        62
# 6               0      1        65
#                 1      1        43
# 7               0      1        39
#                        0        24
#                 1      1        37
#                        0         9
# 8               0      0        77
#                        1         1
#                 1      0        30
# 9               0      0        92
#                 1      0        17
# Name: class, dtype: int64

# %%
testing_analysis.groupby('label')['class'].value_counts()
# Out:
# label  class
# 0      1        263
#        0        193
# 1      1        573
#        0         56
# Name: class, dtype: int64

# %%
for i in testing_analysis.loc[testing_analysis.logit_0_decile == 9].index[30:50]:
    plt.figure()
    row = testing_analysis.iloc[i]
    plt.title('class %f label %f'%(row['class'], row['label']))
    imshow(Image.fromarray((X_test[i,:].reshape((200,200))).astype('uint8'), mode = 'L'))

# %% [markdown]
# SUVs and Verts

# %%
meta_data = pd.read_csv('/home/ec2-user/training_data_meta.csv')

#Join cleaned class data with training metadata

class_data = pd.read_csv('/home/ec2-user/stanford_labels_cleaned.csv')

meta_data = pd.merge(meta_data, class_data, on = 'class', how = 'left')

meta_data = meta_data.loc[meta_data['Body Type'].isin(['SUV', 'Convertible'
                                                      ])].copy()

meta_data['is_sedan_target'] = (meta_data['Body Type'] == 'SUV').astype(int)

image_dict = p.load(open('/home/ec2-user/scaled_bounded_grayscale_dict.p', 'rb'))

oot_data = []
for i in meta_data[['is_sedan_target', 'fname']].iterrows():
    row = [i[1]['is_sedan_target']]
    row.extend(image_dict[i[1]['fname']].flatten())
    oot_data.append(row)

oot_data = np.array(oot_data).astype(float)

# %%
X_oot = oot_data[:,1:]

y_oot = oot_data[:,0].astype('int32')
y_oot = np.concatenate([1 - y_oot.reshape(-1,1), y_oot.reshape(-1,1)], axis = 1)

# %%
print('oot error')
eval_results = car_classifier.evaluate(
    input_fn=lambda:image_processor_eval_input_fn(testing_image_processor, X_oot, y_oot, 32))
print(eval_results)
# Out:
# oot error
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T02:17:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-111848
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-02:18:05
# INFO:tensorflow:Saving dict for global step 111848: eval_accuracy = 0.8368421, global_step = 111848, loss = 149.67972
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 111848: /home/ec2-user/convnet_model/model.ckpt-111848
# {'eval_accuracy': 0.8368421, 'loss': 149.67972, 'global_step': 111848}

# %%
predicted_classes = car_classifier.predict(
    input_fn=lambda:image_processor_eval_input_fn(testing_image_processor, X_oot, y_oot, 32))

testing_analysis = []

for pred, label in zip(predicted_classes, y_oot):
    hold = [pred['probabilities'][1], pred['classes'], label[1], pred['logits'][0], pred['logits'][1]]
    testing_analysis.append(hold)
    
testing_analysis = pd.DataFrame(testing_analysis, columns = ['prob', 'class', 'label', 'logit_0', 'logit_1'])
testing_analysis['logit_1_decile'] = pd.qcut(testing_analysis.logit_1, 10, labels = False)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-111848
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
testing_analysis.groupby(['logit_1_decile', 'label'])['class'].value_counts()
# Out:
# logit_1_decile  label  class
# 0               1      0        38
# 1               1      0        24
#                        1        14
# 2               1      1        38
# 3               1      1        38
# 4               1      1        38
# 5               1      1        38
# 6               1      1        38
# 7               1      1        38
# 8               1      1        38
# 9               1      1        38
# Name: class, dtype: int64

# %%
for i in testing_analysis.loc[testing_analysis.logit_1_decile == 0].index[100:120]:
    plt.figure()
    imshow(Image.fromarray((X_oot[i,:].reshape((200,200))).astype('uint8'), mode = 'L'))

# %%
# Evaluate the model and print results
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": X_train}, y=y_train, num_epochs=1, shuffle=False)
eval_results = car_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-02T02:05:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/ec2-user/convnet_model/model.ckpt-1010
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-02-02:05:40
# INFO:tensorflow:Saving dict for global step 1010: accuracy = 0.9997257, global_step = 1010, loss = 0.04455051
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1010: /home/ec2-user/convnet_model/model.ckpt-1010
# {'accuracy': 0.9997257, 'loss': 0.04455051, 'global_step': 1010}

# %%
Image.fromarray((x_batch[0,:,:,0] * 255).astype('uint8'), mode = 'L')
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F319DFD4BE0>
