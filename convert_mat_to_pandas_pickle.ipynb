# %%
import pandas as pd

from scipy.io import loadmat

# %%
#convert class data from .mat to .csv
#will clean on excel locally

classes = loadmat('/home/ec2-user/raw_data/devkit/cars_meta.mat')

pd.DataFrame([i[0].split(' ') for i in classes['class_names'][0]]).to_csv('/home/ec2-user/hold.csv')

# %%
#convert training metadata from .mat to .csv

training_data_raw = loadmat('/home/ec2-user/raw_data/devkit/cars_train_annos.mat')['annotations'][0]

training_data_flat = []
for i in training_data_raw:
    list_row = list(i)
    training_data_flat.append([j[0][0] for j in list_row[:-1]] + [list_row[-1][0]])

training_data = pd.DataFrame(training_data_flat, columns = ['bbox_x1', 'bbox_y1', 
                                                            'bbox_x2', 'bbox_y2', 
                                                            'class', 'fname'])

training_data.to_csv('/home/ec2-user/training_data_meta.csv', index = False, header = True)

# %%
#Join cleaned class data with training metadata

labels = pd.read_csv('/home/ec2-user/stanford_labels_cleaned.csv')

# %%
pd.merge(training_data, labels, on = 'class', how = 'left')
# Out:
#       bbox_x1  bbox_y1  bbox_x2  bbox_y2  class      fname           Make  \
# 0          39      116      569      375     14  00001.jpg           Audi
# 1          36      116      868      587      3  00002.jpg          Acura
# 2          85      109      601      381     91  00003.jpg          Dodge
# 3         621      393     1484     1096    134  00004.jpg        Hyundai
# 4          14       36      133       99    106  00005.jpg           Ford
# 5         259      289      515      416    123  00006.jpg            Geo
# 6          88       80      541      397     89  00007.jpg          Dodge
# 7          73       79      591      410     96  00008.jpg          Dodge
# 8          20      126     1269      771    167  00009.jpg     Mitsubishi
# 9          21      110      623      367     58  00010.jpg      Chevrolet
# 10         51       93      601      393     49  00011.jpg          Buick
# 11          6       62      499      286    186  00012.jpg         Toyota
# 12         30       36      418      307    135  00013.jpg        Hyundai
# 13         31      246      778      540     85  00014.jpg          Dodge
# 14         32       77      589      379    193  00015.jpg          Volvo
# 15         27       49      611      396    172  00016.jpg       Plymouth
# 16         39       52      233      150     14  00017.jpg           Audi
# 17          3        8      190      147     73  00018.jpg      Chevrolet
# 18        247      287     1366      761    192  00019.jpg     Volkswagen
# 19         17      281      961      596     57  00020.jpg      Chevrolet
# 20         17      156      695      375     79  00021.jpg       Chrysler
# 21        212      538     1893     1131     36  00022.jpg            BMW
# 22         11       28      476      234    120  00023.jpg            GMC
# 23         53      126      973      621    170  00024.jpg         Nissan
# 24         34       87      567      343    194  00025.jpg          Volvo
# 25         30      174      598      379    134  00026.jpg        Hyundai
# 26         80      107      606      336    184  00027.jpg         Suzuki
# 27         45      115      585      382     86  00028.jpg          Dodge
# 28         28      139     1564     1126    180  00029.jpg         Spyker
# 29         82      109      874      521    194  00030.jpg          Volvo
# ...       ...      ...      ...      ...    ...        ...            ...
# 8114     1015      664     1525      989    160  08115.jpg        McLaren
# 8115       25       46      775      555    163  08116.jpg  Mercedes-Benz
# 8116      107      151      932      656     75  08117.jpg      Chevrolet
# 8117       21      127      628      413     32  08118.jpg            BMW
# 8118       27       53      242      148     67  08119.jpg      Chevrolet
# 8119       37      111      582      391    128  08120.jpg          Honda
# 8120       20       32      280      188    153  08121.jpg    Lamborghini
# 8121       15       42      475      318     52  08122.jpg       Cadillac
# 8122       65       55      437      271    178  08123.jpg          Scion
# 8123       10       54      374      212     40  08124.jpg        Bentley
# 8124       24       85      225      159     55  08125.jpg      Chevrolet
# 8125       69       60      603      345    117  08126.jpg           Ford
# 8126       38       29      380      177      5  08127.jpg          Acura
# 8127       61      138      768      526    112  08128.jpg           Ford
# 8128      529      463     1306      808     46  08129.jpg        Bugatti
# 8129       46       31      572      417     46  08130.jpg        Bugatti
# 8130       19       77      619      398    119  08131.jpg            GMC
# 8131       53       65      424      269    153  08132.jpg    Lamborghini
# 8132       57      236      881      569      3  08133.jpg          Acura
# 8133       26       26      300      222    124  08134.jpg         HUMMER
# 8134       53       44      430      293     85  08135.jpg          Dodge
# 8135       54      122      942      590    187  08136.jpg         Toyota
# 8136       30      287      999      658     17  08137.jpg           Audi
# 8137       50      155      637      392    181  08138.jpg         Suzuki
# 8138      117       84      583      403    188  08139.jpg         Toyota
# 8139        3       44      423      336     78  08140.jpg       Chrysler
# 8140      138      150      706      523    196  08141.jpg          smart
# 8141       26      246      660      449    163  08142.jpg  Mercedes-Benz
# 8142       78      526     1489      908    112  08143.jpg           Ford
# 8143       20      240      862      677     17  08144.jpg           Audi
#
#                                  Model    Body Type  Year
# 0                                  TTS        Coupe  2012
# 1                                   TL        Sedan  2012
# 2                               Dakota     Club Cab  2007
# 3                        Sonata Hybrid        Sedan  2012
# 4                     F-450 Super Duty     Crew Cab  2012
# 5                                Metro  Convertible  1993
# 6                              Journey          SUV  2012
# 7                              Charger        Sedan  2012
# 8                               Lancer        Sedan  2012
# 9                             Traverse          SUV  2012
# 10                              Verano        Sedan  2012
# 11                             Sequoia          SUV  2012
# 12                             Elantra        Sedan  2007
# 13                             Caravan      Minivan  1997
# 14                                 C30    Hatchback  2012
# 15                                Neon        Coupe  1999
# 16                                 TTS        Coupe  2012
# 17                              Malibu        Sedan  2007
# 18                              Beetle    Hatchback  2012
# 19    Corvette Ron Fellows Edition Z06        Coupe  2007
# 20                           300 SRT-8        Sedan  2010
# 21                                  M6  Convertible  2010
# 22                        Yukon Hybrid          SUV  2012
# 23                                Juke    Hatchback  2012
# 24                                 240        Sedan  1993
# 25                       Sonata Hybrid        Sedan  2012
# 26                                 SX4        Sedan  2012
# 27                     Ram Pickup 3500     Crew Cab  2010
# 28                                  C8        Coupe  2009
# 29                                 240        Sedan  1993
# ...                                ...          ...   ...
# 8114                           MP4-12C        Coupe  2012
# 8115                          SL-Class        Coupe  2009
# 8116            Silverado 1500 Regular          Cab  2012
# 8117                                X5          SUV  2007
# 8118                     Malibu Hybrid        Sedan  2010
# 8119                            Accord        Coupe  2012
# 8120                            Diablo        Coupe  2001
# 8121                               SRX          SUV  2012
# 8122                                xD    Hatchback  2012
# 8123                            Arnage        Sedan  2009
# 8124                          Corvette  Convertible  2012
# 8125                            Fiesta        Sedan  2012
# 8126                               TSX        Sedan  2012
# 8127                                GT        Coupe  2006
# 8128                       Veyron 16.4        Coupe  2009
# 8129                       Veyron 16.4        Coupe  2009
# 8130                            Savana          Van  2012
# 8131                            Diablo        Coupe  2001
# 8132                                TL        Sedan  2012
# 8133                               H3T     Crew Cab  2010
# 8134                           Caravan      Minivan  1997
# 8135                             Camry        Sedan  2012
# 8136                               100        Sedan  1994
# 8137                             Aerio        Sedan  2007
# 8138                           Corolla        Sedan  2012
# 8139                  Town and Country      Minivan  2012
# 8140                            fortwo  Convertible  2012
# 8141                          SL-Class        Coupe  2009
# 8142                                GT        Coupe  2006
# 8143                               100        Sedan  1994
#
# [8144 rows x 10 columns]

# %%
from IPython.display import Image

Image(filename='/home/ec2-user/00001.jpg')
